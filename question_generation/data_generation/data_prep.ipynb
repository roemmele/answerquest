# %%
import os
import pandas
import pickle
import importlib
import random
from IPython.display import display

import data_utils
importlib.reload(data_utils)

pandas.set_option('display.max_colwidth', -1)
pandas.set_option('display.max_rows', 500)

random.seed(0)

# %% [markdown]
# ## Create a validation set from existing training dataset
#
# Use this set for validation when training question generation model, so that provided validation data can instead be used as a held-out test set.

# %%
data_dir = '''/home/mroemmele/question_generation/newsqa_rule_generated_data/untok_data/'''
percent_heldout = 0.02

# %%
'''Load training data'''

answer_sents = [sent.strip()
                for sent in open(os.path.join(data_dir, 'train', 'answer_sents.txt'))]
questions = [question.strip()
             for question in open(os.path.join(data_dir, 'train', 'questions.txt'))]
answers = [answer.strip()
           for answer in open(os.path.join(data_dir, 'train', 'answers_only.txt'))]
paragraphs = [paragrasph.strip()
              for paragraph in open(os.path.join(data_dir, 'train', 'paragraphs.txt'))]
#paragraphs = [""] * len(answer_sents)

# %%
'''Randomly select indices of heldout data items or load them from file'''

rand_idxs = list(range(len(answer_sents)))
random.shuffle(rand_idxs)
n_heldout = int(percent_heldout * len(answer_sents))
heldout_idxs = set(rand_idxs[:n_heldout])

# with open("/home/mroemmele/question_generation/squad_rule_mimic_heldout_train_idxs_2_percent.pkl", 'rb') as f:
#     heldout_idxs = pickle.load(f)

list(heldout_idxs)[:10]
# Out:
# [131072, 786435, 393231, 917525, 21, 262167, 262166, 786457, 131097, 917533]

# %%
'''Save the random indices so they can be used for other datasets (only run if new indices generated)'''

with open(os.path.join(data_dir, "heldout_train_idxs_2_percent.pkl"), 'wb') as f:
    pickle.dump(heldout_idxs, f)

# %%
'''Partition out validation data from training data by randomly selecting items'''

train_paragraphs, train_answer_sents, train_questions, train_answers = [], [], [], []
valid_paragraphs, valid_answer_sents, valid_questions, valid_answers = [], [], [], []

for idx, (paragraph, answer_sent,
          question, answer) in enumerate(zip(paragraphs, answer_sents, questions, answers)):
    #import pdb;pdb.set_trace()
    if idx in heldout_idxs:
        valid_paragraphs.append(paragraph)
        valid_answer_sents.append(answer_sent)
        valid_questions.append(question)
        valid_answers.append(answer)
    else:
        train_paragraphs.append(paragraph)
        train_answer_sents.append(answer_sent)
        train_questions.append(question)
        train_answers.append(answer)

assert len(train_paragraphs) == len(train_answer_sents) == len(train_questions) == len(train_answers)
assert len(valid_paragraphs) == len(valid_answer_sents) == len(valid_questions) == len(valid_answers)

# %%
'''Save partitioned data'''

if not os.path.isdir(os.path.join(data_dir, 'valid')):
    os.mkdir(os.path.join(data_dir, 'valid'))
    
#Save train    
with open(os.path.join(data_dir, 'train', 'paragraphs.txt'), 'w') as f:
    f.write("\n".join(train_paragraphs))
    
with open(os.path.join(data_dir, 'train', 'answer_sents.txt'), 'w') as f:
    f.write("\n".join(train_answer_sents))

with open(os.path.join(data_dir, 'train', 'questions.txt'), 'w') as f:
    f.write("\n".join(train_questions))

with open(os.path.join(data_dir, 'train', 'answers_only.txt'), 'w') as f:
    f.write("\n".join(train_answers))
    
#Save valid
with open(os.path.join(data_dir, 'valid', 'paragraphs.txt'), 'w') as f:
    f.write("\n".join(valid_paragraphs))
    
with open(os.path.join(data_dir, 'valid', 'answer_sents.txt'), 'w') as f:
    f.write("\n".join(valid_answer_sents))

with open(os.path.join(data_dir, 'valid', 'questions.txt'), 'w') as f:
    f.write("\n".join(valid_questions))
    
with open(os.path.join(data_dir, 'valid', 'answers_only.txt'), 'w') as f:
    f.write("\n".join(valid_answers))

# %% [markdown]
# ## Concatenate two datasets into one

# %%
data_dir1 = "/home/mroemmele/question_generation/squad_untok_data/"
data_dir2 = "/home/mroemmele/question_generation/newsqa_untok_data/"
partition = 'test'

# %%
'''Load datasets for given partition'''

paragraphs1 = [paragraph.strip()
              for paragraph in open(os.path.join(data_dir1, partition, 'paragraphs.txt'))]
answer_sents1 = [sent.strip()
                for sent in open(os.path.join(data_dir1, partition, 'answer_sents.txt'))]
questions1 = [question.strip()
             for question in open(os.path.join(data_dir1, partition, 'questions.txt'))]
answers1 = [answer.strip()
           for answer in open(os.path.join(data_dir1, partition, 'answers_only.txt'))]
assert len(paragraphs1) == len(answer_sents1) == len(questions1) == len(answers1)

paragraphs2 = [paragraph.strip()
              for paragraph in open(os.path.join(data_dir2, partition, 'paragraphs.txt'))]
answer_sents2 = [sent.strip()
                for sent in open(os.path.join(data_dir2, partition, 'answer_sents.txt'))]
questions2 = [question.strip()
             for question in open(os.path.join(data_dir2, partition, 'questions.txt'))]
answers2 = [answer.strip()
           for answer in open(os.path.join(data_dir2, partition, 'answers_only.txt'))]
assert len(paragraphs2) == len(answer_sents2) == len(questions2) == len(answers2)

# %%
'''Concatenate'''

paragraphs = paragraphs1 + paragraphs2
answer_sents = answer_sents1 + answer_sents2
questions = questions1 + questions2
answers = answers1 + answers2
assert len(paragraphs) == len(answer_sents) == len(questions) == len(answers)

# %%
len(answers)
# Out:
# 14911

# %%
concat_data_dir = "/home/mroemmele/question_generation/squad_newsqa_untok_data/"

if not os.path.isdir(concat_data_dir):
    os.mkdir(concat_data_dir)

# %%
'''Shuffle the new dataset, if partition is training'''

if partition == 'train':
    rand_idxs = list(range(len(answer_sents)))
    random.shuffle(rand_idxs)

    #Save shuffle indices in case
    with open(os.path.join(concat_data_dir, "shuffle_order_train_indices.pkl"), 'wb') as f:
        pickle.dump(rand_idxs, f)

    paragraphs = [paragraphs[idx] for idx in rand_idxs]
    answer_sents = [answer_sents[idx] for idx in rand_idxs]
    questions = [questions[idx] for idx in rand_idxs]
    answers = [answers[idx] for idx in rand_idxs]

# %%
pandas.DataFrame({'answer_sent': answer_sents, 'question': questions})
# Out:
#                                                                                                                                                                                                                                                                                                                                                                           answer_sent  \
# 0      The American Football Conference (AFC) champion <ANSWER> Denver Broncos </ANSWER> defeated the National Football Conference (NFC) champion Carolina Panthers 24–10 to earn their third Super Bowl title.
# 1      The American Football Conference (AFC) champion Denver Broncos defeated the National Football Conference (NFC) champion <ANSWER> Carolina Panthers </ANSWER> 24–10 to earn their third Super Bowl title.
# 2      The game was played on February 7, 2016, at <ANSWER> Levi's Stadium in the San Francisco Bay Area at Santa Clara, California. </ANSWER>
# 3      The American Football Conference (AFC) champion <ANSWER> Denver Broncos </ANSWER> defeated the National Football Conference (NFC) champion Carolina Panthers 24–10 to earn their third Super Bowl title.
# 4      As this was the 50th Super Bowl, the league emphasized the "<ANSWER> gold </ANSWER>en anniversary" with various gold-themed initiatives, as well as temporarily suspending the tradition of naming each Super Bowl game with Roman numerals (under which the game would have been known as "Super Bowl L"), so that the logo could prominently feature the Arabic numerals 50.
# ...                                                                                                                                                                                                                                                                                                                                                                               ...
# 14906  "A total of <ANSWER> seven </ANSWER> died on our property," O'Connor told CNN.
# 14907  Teams are trying to figure out what happened at the <ANSWER> International Polo Club Palm Beach in Florida. </ANSWER>
# 14908  Fourteen thoroughbred horses dropped dead in a mysterious scene Sunday before a polo match near <ANSWER> West Palm Beach, Florida, </ANSWER> officials said.
# 14909  The cause of the deaths <ANSWER> has not been determined, </ANSWER> and necropsies and blood tests were underway, he said.
# 14910  <ANSWER> Fourteen </ANSWER> thoroughbred horses dropped dead in a mysterious scene Sunday before a polo match near West Palm Beach, Florida, officials said.
#
#                                                                        question
# 0      Which NFL team represented the AFC at Super Bowl 50?
# 1      Which NFL team represented the NFC at Super Bowl 50?
# 2      Where did Super Bowl 50 take place?
# 3      Which NFL team won Super Bowl 50?
# 4      What color was used to emphasize the 50th anniversary of the Super Bowl?
# ...                                                                         ...
# 14906  How many horses died?
# 14907  Where were the races held?
# 14908  Where was the match set?
# 14909  What was the reason that horses die?
# 14910  How many horsed died?
#
# [14911 rows x 2 columns]

# %%
'''Save new dataset'''

if not os.path.isdir(os.path.join(concat_data_dir, partition)):
    os.mkdir(os.path.join(concat_data_dir, partition))
     
with open(os.path.join(concat_data_dir, partition, 'paragraphs.txt'), 'w') as f:
    f.write("\n".join(paragraphs))
    
with open(os.path.join(concat_data_dir, partition, 'answer_sents.txt'), 'w') as f:
    f.write("\n".join(answer_sents))

with open(os.path.join(concat_data_dir, partition, 'questions.txt'), 'w') as f:
    f.write("\n".join(questions))

with open(os.path.join(concat_data_dir, partition, 'answers_only.txt'), 'w') as f:
    f.write("\n".join(answers))

# %% [markdown]
# ## Create entity-masked dataset

# %%
def mask_entities_in_data(input_texts, questions, ignore_tokens=["<ANSWER>", "</ANSWER>"]):
    masked_input_texts = []
    masked_questions = []
    tokens_to_tags = []
    for input_text, question in zip(input_texts, questions):
        item_tokens_to_tags = data_utils.get_tokens_to_tags(input_text + " " + question,
                                                            ignore_tokens)
        (masked_input_text, masked_question,
         item_tokens_to_tags) = data_utils.mask_entity_tokens(input_text,
                                                              question,
                                                              item_tokens_to_tags)
        masked_input_texts.append(masked_input_text)
        masked_questions.append(masked_question)
        tokens_to_tags.append(item_tokens_to_tags)
    return {'input_text': masked_input_texts, 
            'question': masked_questions, 
            'tokens_to_tags': tokens_to_tags}

# %%
'''Load QG data'''

data_dir = "/home/mroemmele/question_generation/squad_untok_data/"
partition = 'test'
qg_data = {'input_text': [text.strip() for text in open(os.path.join(data_dir, partition, "answer_sents.txt"))],
          'question': [question.strip() for question in open(os.path.join(data_dir, partition, "questions.txt"))]}

# %%
'''Apply masking'''

masked_qg_data = mask_entities_in_data(qg_data['input_text'][:10], qg_data['question'][:10])
pandas.DataFrame(masked_qg_data)[-100:]

# %%
'''Save the masked dataset'''

data_dir = "/home/mroemmele/question_generation/squad_entity_masked_data"

if not os.path.isdir(os.path.join(data_dir, partition)):
    os.mkdir(os.path.join(data_dir, partition))
    
with open(os.path.join(data_dir, partition, 'answer_sents.txt'), 'w') as f:
    f.write("\n".join(masked_qg_data['input_text']))

with open(os.path.join(data_dir, partition, 'questions.txt'), 'w') as f:
    f.write("\n".join(masked_qg_data['question']))
    
with open(os.path.join(data_dir, partition, 'tokens_to_tags.pkl'), 'wb') as f:
    pickle.dump(masked_qg_data['tokens_to_tags'], f)

# %% [markdown]
# ## Create tokenized dataset as input to QG system

# %%
def tokenize_data(input_texts, questions, tokenizer, tokenize_fn, entity_masking=False):
    # Add special character after answer/entity annotations so tokenizer will respect space
    tok_input_texts = []
    tok_questions = []
    for idx, (input_text, question) in enumerate(zip(input_texts, questions)):
        tok_question = " ".join(tokenize_fn(tokenizer, question))
        tok_questions.append(tok_question)
        tok_input_text = " ".join(tokenize_fn(tokenizer, input_text, handle_entities=entity_masking))
        tok_input_texts.append(tok_input_text)
        if idx and idx % 10000 == 0:
            print(idx)
    return {'input_text': tok_input_texts,
            'question': tok_questions}

# %%
'''Load tokenizer and define special tokens to respect, or load tokenizer if already saved'''

from transformers import GPT2Tokenizer

tokenizer_dirpath = "/home/mroemmele/question_generation/gpt2_tokenizer_vocab/"

if not os.path.isdir(tokenizer_dirpath):
    tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
    # Add special tokens for designating answers in squad texts
    special_tokens = ["<ANSWER>", "</ANSWER>"]
    # Add entity tags as special tokens (each tag indexed up to 100)
    special_tokens.extend(["Ġ<{}".format(tag) for tag in data_utils.ENTITY_TAGS])
    special_tokens.extend(["<{}".format(tag) for tag in data_utils.ENTITY_TAGS])
    special_tokens.extend(["_{}>".format(num) for num in range(1,101)])
    tokenizer.add_tokens(special_tokens)
    #Save tokenizer vocab with special tokens added
    tokenizer.save_pretrained(tokenizer_dirpath)
else:
    tokenizer = GPT2Tokenizer.from_pretrained(tokenizer_dirpath)

# %%
'''Load data'''

data_dir = "/home/mroemmele/question_generation/squad_newsqa_untok_data/"
partition = 'test'
entity_masking = False
qg_data = {'input_text': [text.strip() for text in open(os.path.join(data_dir, partition, "answer_sents.txt"))],
           'question': [question.strip() for question in open(os.path.join(data_dir, partition, "questions.txt"))]}
if entity_masking:
    qg_data['tokens_to_tags'] = pickle.load(open(os.path.join(data_dir, partition, "tokens_to_tags.pkl"), 'rb'))

# %%
pandas.DataFrame(qg_data)[1000:1500]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                      input_text  \
# 1000  They have extensive botanical collection of rare domestic and foreign plants, while a palm house in the <ANSWER> New Orangery </ANSWER> displays plants of subtropics from all over the world.
# 1001  Besides, within the city borders, there are also: <ANSWER> Pole Mokotowskie </ANSWER> (a big park in the northern Mokotów, where was the first horse racetrack and then the airport), Park Ujazdowski (close to the Sejm and John Lennon street), Park of Culture and Rest in Powsin, by the southern city border, Park Skaryszewski by the right Vistula bank, in Praga.
# 1002  Besides, within the city borders, there are also: Pole Mokotowskie (a big park in the northern Mokotów, where was the first horse racetrack and then the airport), <ANSWER> Park Ujazdowski </ANSWER> (close to the Sejm and John Lennon street), Park of Culture and Rest in Powsin, by the southern city border, Park Skaryszewski by the right Vistula bank, in Praga.
# 1003  In <ANSWER> 1927 </ANSWER> a zoological garden (Ogród Zoologiczny) was established on the park grounds, and in 1952 a bear run, still open today.
# 1004  The species richness is mainly due to the <ANSWER> location of Warsaw </ANSWER> within the border region of several big floral regions comprising substantial proportions of close-to-wilderness areas (natural forests, wetlands along the Vistula) as well as arable land, meadows and forests.
# 1005  Bielany Forest, located <ANSWER> within the borders of Warsaw </ANSWER>, is the remaining part of the Masovian Primeval Forest.
# 1006  Bielany Forest, located within the borders of Warsaw, is the remaining part of the <ANSWER> Masovian Primeval Forest </ANSWER>.
# 1007  Other big forest area is <ANSWER> Kabaty Forest </ANSWER> by the southern city border.
# 1008  Warsaw has also <ANSWER> two </ANSWER> botanic gardens: by the Łazienki park (a didactic-research unit of the University of Warsaw) as well as by the Park of Culture and Rest in Powsin (a unit of the Polish Academy of Science).
# 1009  In 1939, c. <ANSWER> 1,300,000 </ANSWER> people lived in Warsaw, but in 1945 – only 420,000.
# 1010  In 1939, c. 1,300,000 people lived in Warsaw, but in 1945 – only <ANSWER> 420,000 </ANSWER>.
# 1011  The first remedial measure was the Warsaw area enlargement (<ANSWER> 1951 </ANSWER>)
# 1012  It also bolstered some kind of conviction among Poles that Varsovians <ANSWER> thought of themselves as better </ANSWER> only because they lived in the capital.
# 1013  – even though since 1990 there are no limitations to <ANSWER> residency registration </ANSWER> anymore.
# 1014  Throughout its existence, Warsaw has been a <ANSWER> multi-cultural city </ANSWER>.
# 1015  According to the 1901 census, out of <ANSWER> 711,988 </ANSWER> inhabitants 56.2% were Catholics, 35.7% Jews, 5% Greek orthodox Christians and 2.8% Protestants.
# 1016  According to the 1901 census, out of 711,988 inhabitants <ANSWER> 56.2% </ANSWER> were Catholics, 35.7% Jews, 5% Greek orthodox Christians and 2.8% Protestants.
# 1017  According to the 1901 census, out of 711,988 inhabitants 56.2% were Catholics, 35.7% Jews, 5% Greek orthodox Christians and <ANSWER> 2.8% </ANSWER> Protestants.
# 1018  Most of them were destroyed in the aftermath of the Warsaw Uprising of <ANSWER> 1944 </ANSWER>.
# 1019  The basic unit of territorial division in Poland is <ANSWER> a commune </ANSWER> (gmina).
# 1020  Some bigger cities obtain the entitlements, i.e. tasks and privileges, which are possessed by the units of the second level of the territorial division – <ANSWER> counties or powiats </ANSWER>.
# 1021  But for instance the districts in <ANSWER> Kraków </ANSWER> do not have entitlements of powiat, so the registration numbers in Kraków are of the same type for all districts.
# 1022  Legislative power in Warsaw is vested in a unicameral <ANSWER> Warsaw City Council </ANSWER> (Rada Miasta), which comprises 60 members.
# 1023  Legislative power in Warsaw is vested in a unicameral Warsaw City Council (Rada Miasta), which comprises <ANSWER> 60 </ANSWER> members.
# 1024  Council members are elected directly <ANSWER> every four years. </ANSWER>
# 1025  Like most legislative bodies, the City Council divides itself into <ANSWER> committees </ANSWER> which have the oversight of various functions of the city government.
# 1026  If the mayor vetoes a bill, the Council has <ANSWER> 30 days </ANSWER> to override the veto by a two-thirds majority vote.
# 1027  The mayor of Warsaw is called <ANSWER> President </ANSWER>.
# 1028  The first Warsaw President was <ANSWER> Jan Andrzej Menich </ANSWER> (1695–1696).
# 1029  The first Warsaw President was Jan Andrzej Menich (<ANSWER> 1695–1696 </ANSWER>).
# 1030  Since 1990 the President of Warsaw had been elected by <ANSWER> the City council </ANSWER>.
# 1031  In the years of 1994–1999 the mayor of the district <ANSWER> Centrum </ANSWER> automatically was designated as the President of Warsaw: the mayor of Centrum was elected by the district council of Centrum and the council was elected only by the Centrum residents.
# 1032  Warsaw, especially its city centre (<ANSWER> Śródmieście </ANSWER>), is home not only to many national institutions and government agencies, but also to many domestic and international companies.
# 1033  In 2006, <ANSWER> 304,016 </ANSWER> companies were registered in the city.
# 1034  Moreover, Warsaw was ranked as the 7th greatest <ANSWER> emerging market </ANSWER>.
# 1035  Warsaw produces <ANSWER> 12% </ANSWER> of Poland's national income, which in 2008 was 305.1% of the Polish average, per capita (or 160% of the European Union average).
# 1036  Total nominal GDP of the city in 2010 amounted to <ANSWER> 191.766 billion PLN </ANSWER>, 111696 PLN per capita, which was 301,1 % of Polish average.
# 1037  Warsaw's first stock exchange was established in <ANSWER> 1817 </ANSWER> and continued trading until World War II.
# 1038  Warsaw's first stock exchange was established in 1817 and continued trading until <ANSWER> World War II. </ANSWER>
# 1039  It was re-established in <ANSWER> April 1991 </ANSWER>, following the end of the post-war communist control of the country and the reintroduction of a free-market economy.
# 1040  Today, the Warsaw Stock Exchange (WSE) is, according to many indicators, the largest market in the region, with <ANSWER> 374 </ANSWER> companies listed and total capitalization of 162 584 mln EUR as of 31 August 2009.
# 1041  From 1991 until 2000, the stock exchange was, ironically, located in the building previously used as the headquarters of the <ANSWER> Polish United Workers' Party </ANSWER> (PZPR).
# 1042  The FSO Car Factory was established in <ANSWER> 1951 </ANSWER>.
# 1043  A number of vehicles have been assembled there over the decades, including the Warszawa, Syrena, Fiat 125p (under license from Fiat, later renamed FSO 125p when the license expired) and the <ANSWER> Polonez </ANSWER>.
# 1044  In 1995 the factory was purchased by the South Korean car manufacturer <ANSWER> Daewoo </ANSWER>, which assembled the Tico, Espero, Nubia, Tacuma, Leganza, Lanos and Matiz there for the European market.
# 1045  In 2005 the factory was sold to <ANSWER> AvtoZAZ </ANSWER>, a Ukrainian car manufacturer which assembled there the Chevrolet Aveo.
# 1046  In 2005 the factory was sold to AvtoZAZ, a Ukrainian car manufacturer which assembled there the <ANSWER> Chevrolet Aveo </ANSWER>.
# 1047  <ANSWER> Warszawa </ANSWER> [varˈʂava]
# 1048  <ANSWER> Warsaw </ANSWER> (Polish:
# 1049  It stands on the <ANSWER> Vistula River </ANSWER> in east-central Poland, roughly 260 kilometres (160 mi) from the Baltic Sea and 300 kilometres (190 mi) from the Carpathian Mountains.
# 1050  Its population is estimated at 1.740 million residents within a greater metropolitan area of <ANSWER> 2.666 million residents </ANSWER>, which makes Warsaw the 9th most-populous capital city in the European Union.
# 1051  Its population is estimated at 1.740 million residents within a greater metropolitan area of 2.666 million residents, which makes Warsaw the <ANSWER> 9th </ANSWER> most-populous capital city in the European Union.
# 1052  <ANSWER> Warsaw </ANSWER> (Polish:
# 1053  It stands on the <ANSWER> Vistula River </ANSWER> in east-central Poland, roughly 260 kilometres (160 mi) from the Baltic Sea and 300 kilometres (190 mi) from the Carpathian Mountains.
# 1054  It stands on the Vistula River in east-central Poland, <ANSWER> roughly 260 kilometres </ANSWER> (160 mi) from the Baltic Sea and 300 kilometres (190 mi) from the Carpathian Mountains.
# 1055  Its population is estimated at 1.740 million residents within a greater metropolitan area of <ANSWER> 2.666 million </ANSWER> residents, which makes Warsaw the 9th most-populous capital city in the European Union.
# 1056  Its population is estimated at 1.740 million residents within a greater metropolitan area of 2.666 million residents, which makes Warsaw the <ANSWER> 9th </ANSWER> most-populous capital city in the European Union.
# 1057  The Normans (Norman: Nourmands; French: Normands; Latin: Normanni) were the people who in the 10th and 11th centuries gave their name to Normandy, a region in <ANSWER> France </ANSWER>.
# 1058  The Normans (Norman: Nourmands; French: Normands; Latin: Normanni) were the people who <ANSWER> in the 10th and 11th centuries </ANSWER> gave their name to Normandy, a region in France.
# 1059  They were descended from Norse ("Norman" comes from "Norseman") raiders and pirates from <ANSWER> Denmark, Iceland and Norway </ANSWER> who, under their leader Rollo, agreed to swear fealty to King Charles III of West Francia.
# 1060  They were descended from Norse ("Norman" comes from "Norseman") raiders and pirates from Denmark, Iceland and Norway who, under their leader <ANSWER> Rollo </ANSWER>, agreed to swear fealty to King Charles III of West Francia.
# 1061  The distinct cultural and ethnic identity of the Normans emerged initially in <ANSWER> the first half of the 10th century </ANSWER>, and it continued to evolve over the succeeding centuries.
# 1062  Norman adventurers founded the Kingdom of Sicily under Roger II after conquering southern Italy on the Saracens and Byzantines, and an expedition on behalf of their duke, <ANSWER> William the Conqueror </ANSWER>, led to the Norman conquest of England at the Battle of Hastings in 1066.
# 1063  The Duchy of Normandy, which they formed by treaty with the French crown, was a great fief of medieval France, and under <ANSWER> Richard I </ANSWER> of Normandy was forged into a cohesive and formidable principality in feudal tenure.
# 1064  The Normans were famed for their martial spirit and eventually for their Christian piety, becoming exponents of the <ANSWER> Catholic orthodoxy </ANSWER> into which they assimilated.
# 1065  The English name "Normans" comes from the French words Normans/Normanz, plural of Normant, modern French normand, which is itself borrowed from Old Low Franconian Nortmann "Northman" or directly from Old Norse Norðmaðr, Latinized variously as Nortmannus, Normannus, or Nordmannus (recorded in Medieval Latin, 9th century) to mean "<ANSWER> Norseman, Viking </ANSWER>".
# 1066  The English name "Normans" comes from the French words Normans/Normanz, plural of Normant, modern French normand, which is itself borrowed from Old Low Franconian Nortmann "Northman" or directly from Old Norse Norðmaðr, Latinized variously as Nortmannus, Normannus, or Nordmannus (recorded in Medieval Latin, <ANSWER> 9th century </ANSWER>) to mean "Norseman, Viking".
# 1067  The Duchy of Normandy, which began in <ANSWER> 911 </ANSWER> as a fiefdom, was established by the treaty of Saint-Clair-sur-Epte between King Charles III of West Francia and the famed Viking ruler Rollo, and was situated in the former Frankish kingdom of Neustria.
# 1068  The Duchy of Normandy, which began in 911 as a fiefdom, was established by the treaty of Saint-Clair-sur-Epte between <ANSWER> King Charles III </ANSWER> of West Francia and the famed Viking ruler Rollo, and was situated in the former Frankish kingdom of Neustria.
# 1069  The area corresponded to the northern part of present-day Upper Normandy down to the river <ANSWER> Seine </ANSWER>, but the Duchy would eventually extend west beyond the Seine.
# 1070  Before <ANSWER> Rollo </ANSWER>'s arrival, its populations did not differ from Picardy or the Île-de-France, which were considered "Frankish".
# 1071  The descendants of Rollo's Vikings and their Frankish wives would replace the Norse religion and Old Norse language with <ANSWER> Catholicism </ANSWER> (Christianity) and the Gallo-Romance language of the local people, blending their maternal Frankish heritage with Old Norse traditions and customs to synthesize a unique "Norman" culture in the north of France.
# 1072  The descendants of Rollo's Vikings and their Frankish wives would replace the Norse religion and Old Norse language with Catholicism (Christianity) and the Gallo-Romance language of the local people, blending their maternal Frankish heritage with Old Norse traditions and customs to synthesize a unique "Norman" culture in <ANSWER> the north </ANSWER> of France.
# 1073  Most Norman knights remained poor and land-hungry, and by 1066 Normandy had been exporting <ANSWER> fighting horsemen </ANSWER> for more than a generation.
# 1074  <ANSWER> In 999 </ANSWER>, according to Amatus of Montecassino, Norman pilgrims returning from Jerusalem called in at the port of Salerno when a Saracen attack occurred.
# 1075  William of Apulia tells that, in 1016, Norman pilgrims to the shrine of <ANSWER> the Archangel Michael </ANSWER> at Monte Gargano were met by Melus of Bari, a Lombard nobleman and rebel, who persuaded them to return with more warriors to help throw off the Byzantine rule, which they did.
# 1076  William of Apulia tells that, in 1016, Norman pilgrims to the shrine of the Archangel Michael <ANSWER> at Monte Gargano </ANSWER> were met by Melus of Bari, a Lombard nobleman and rebel, who persuaded them to return with more warriors to help throw off the Byzantine rule, which they did.
# 1077  The Drengot family thereafter attained the principality of Capua, and emperor Henry III legally ennobled the Hauteville leader, <ANSWER> Drogo </ANSWER>, as "dux et magister Italiae comesque
# 1078  He promptly awarded their elected leader, <ANSWER> William Iron Arm </ANSWER>, with the title of count in his capital of Melfi.
# 1079  From these bases, the Normans eventually captured Sicily and Malta from <ANSWER> the Saracens </ANSWER>, under the leadership of the famous Robert Guiscard, a Hauteville, and his younger brother Roger the Great Count.
# 1080  Roger's son, Roger II of Sicily, was crowned king in <ANSWER> 1130 </ANSWER> (exactly one century after Rainulf was "crowned" count) by Antipope Anacletus II.
# 1081  The Normans left their legacy in many castles, such as William Iron Arm's citadel at <ANSWER> Squillace </ANSWER>, and cathedrals, such as Roger II's Cappella Palatina chapel at Palermo, which dot the landscape and give a wholly distinct architectural flavor to accompany its unique history.
# 1082  One of the great geographical treatises of the Middle Ages, the "Tabula Rogeriana", was written by the Andalusian al-Idrisi for king Roger II of Sicily, and entitled "<ANSWER> Kitab Rudjdjar </ANSWER>" ("The Book of Roger").
# 1083  One of the great geographical treatises of the Middle Ages, the "Tabula Rogeriana", was written by the Andalusian al-Idrisi for king Roger II of Sicily, and entitled "Kitab Rudjdjar" ("<ANSWER> The Book of Roger </ANSWER>").
# 1084  Under this state, there was great religious freedom, and alongside the Norman nobles existed a <ANSWER> meritocratic </ANSWER> bureaucracy of Jews, Muslims and Christians, both Catholic and Eastern Orthodox.
# 1085  Soon after the Normans began to enter Italy, they entered the Byzantine Empire and then Armenia, fighting against <ANSWER> the Pechenegs, the Bulgars, and especially the Seljuk Turks </ANSWER>.
# 1086  One of the first Norman mercenaries to serve as a Byzantine general was Hervé <ANSWER> in the 1050s </ANSWER>.
# 1087  <ANSWER> In the 1060s </ANSWER>, Robert Crispin led the Normans of Edessa against the Turks.
# 1088  Roussel de Bailleul even tried to carve out an independent state in Asia Minor with support from the local population, but he was stopped by the Byzantine general <ANSWER> Alexius Komnenos </ANSWER>.
# 1089  They even lent their ethnicity to the name of their castle: <ANSWER> Afranji </ANSWER>, meaning "Franks.
# 1090  A Norman named <ANSWER> Oursel </ANSWER> led a force of "Franks" into the upper Euphrates valley in northern Syria.
# 1091  Some Normans joined <ANSWER> Turkish forces </ANSWER> to aid in the destruction of the Armenians vassal-states of Sassoun and Taron in far eastern Anatolia.
# 1092  The Raoulii were <ANSWER> descended from an Italo-Norman named Raoul </ANSWER>, the Petraliphae were descended from a Pierre d'Aulps, and that group of Albanian clans known as the Maniakates were descended from Normans who served under George Maniaces in the Sicilian expedition of 1038.
# 1093  <ANSWER> Robert Guiscard </ANSWER>, an other Norman adventurer previously elevated to the dignity of count of Apulia as the result of his military successes, ultimately drove the Byzantines out of southern Italy.
# 1094  The city's garrison resisted until <ANSWER> February 1082 </ANSWER>, when Dyrrachium was betrayed to the Normans by the Venetian and Amalfitan merchants who had settled there.
# 1095  After allying himself with Croatia and the Catholic cities of Dalmatia, in 1081 he led an army of <ANSWER> 30,000 </ANSWER> men in 300 ships landing on the southern shores of Albania, capturing Valona, Kanina, Jericho (Orikumi), and reaching Butrint after numerous pillages.
# 1096  Meanwhile, they occupied Petrela, the citadel of Mili at the banks of the river <ANSWER> Deabolis </ANSWER>, Gllavenica (Ballsh), Kanina and Jericho.
# 1097  A few years after the First Crusade, in 1107, the Normans under the command of <ANSWER> Bohemond </ANSWER>, Robert's son, landed in Valona and besieged Dyrrachium using the most sophisticated military equipment of the time, but to no avail.
# 1098  Meanwhile, they occupied Petrela, the citadel of Mili at the banks of <ANSWER> the river Deabolis </ANSWER>, Gllavenica (Ballsh), Kanina and Jericho.
# 1099  The further decline of Byzantine state-of-affairs paved the road to a third attack <ANSWER> in 1185 </ANSWER>, when a large Norman army invaded Dyrrachium, owing to the betrayal of high Byzantine officials.
# 1100  The further decline of Byzantine state-of-affairs paved the road to a third attack in 1185, when a large Norman army invaded <ANSWER> Dyrrachium </ANSWER>, owing to the betrayal of high Byzantine officials.
# 1101  one of the most important naval bases of <ANSWER> the Adriatic </ANSWER>—fell again to Byzantine hands.
# 1102  This relationship eventually produced closer ties of blood through the marriage of Emma, sister of Duke Richard II of Normandy, and <ANSWER> King Ethelred II </ANSWER> of England.
# 1103  This relationship eventually produced closer ties of blood through the marriage of Emma, sister of <ANSWER> Duke Richard II </ANSWER> of Normandy, and King Ethelred II of England.
# 1104  Because of this, Ethelred fled to <ANSWER> Normandy </ANSWER> in 1013, when he was forced from his kingdom by Sweyn Forkbeard.
# ...
# 1377  Who took control of Edison's company.
# 1378  In 1893, who won the bid to light the World's Columbian Exposition?
# 1379  Where was the 1893 World's Columbian Exposition held?
# 1380  Who did George Westinghouse beat out to light the World's Columbian Exposition?
# 1381  What did Tesla call his electrical effects in 1893?
# 1382  What was it called when Tesla lit a wireless gas-discharge lamp using a high-frequency, high-voltage alternating current?
# 1383  Who outbid General Electric to provide light to the World's Columbian Exposition?
# 1384  Where did the Exposition take place?
# 1385  In what year was the World's Columbian Exposition?
# 1386  What type of power was displayed at the World's fair by Westinghouse and Tesla?
# 1387  Who headed the Niagara Falls Cataract Construction Company in 1893?
# 1388  What landmark was Tesla asked about in regards to electricity in 1893?
# 1389  What company was chosen to build a two-phase AC generating system at Niagara Falls?
# 1390  What company was chosen to build an AC distribution system at Niagara Falls?
# 1391  What system did Tesla recommend to Niagara Falls in 1893?
# 1392  Who was the head of the company?
# 1393  When did Richard Dean Adams make his inquiry?
# 1394  What type of system did Tesla suggest to Adams?
# 1395  What was the advantage of the two-phased system
# 1396  When was a patent-sharing agreement signed between Westinghouse Electric and General Electric?
# 1397  How much did Tesla sell his AC patents to Westinghouse Electric for?
# 1398  What was the overly generous royalty amount that Tesla had been receiving?
# 1399  By 1897, how much had Tesla, Brown, and Peck received in royalties and licenses over the patents?
# 1400  Who financed General Electric's attempts to takeover Westinghouse?
# 1401  How much had Westinghouse paid to Tesla, Brown and Peck?
# 1402  How much did Westinghouse pay for Tesla's patents in order to escape its financial problems?
# 1403  How old was tesla when he became a US citizen?
# 1404  Where was Tesla's laboratory established?
# 1405  What did he light at his laboratories to demonstrate his wireless power transmission?
# 1406  what did he patent in 1891?
# 1407  When did Tesla get his US citizenship?
# 1408  What did Tesla patent in 1891?
# 1409  How old was Tesla when he became a citizen of the US?
# 1410  What sort of power transmission did Tesla show off at his labs?
# 1411  What organization did Tesla serve as vice president of?
# 1412  What was the forerunner of the modern-day IEEE?
# 1413  When did Tesla stop serving as the vice president of American Institute of Electrical Engineers?
# 1414  What position did Tesla hold in the American Institute of Electrical Engineers?
# 1415  How long did Tesla hold this position?
# 1416  Along with the American Institute of Electrical Engineers what other institute eventually became the IEEE?
# 1417  Why did Tesla begin investigating invisible energy?
# 1418  What took place in his lab in 1895, causing him to lose thousands of dollars of data and tools?
# 1419  When were x-rays discovered?
# 1420  When Tesla attempted to photograph Mark Twain, what was the only thing that showed up on the image?
# 1421  When die Tesla turn his attention to trying to understand invisible radiant energy?
# 1422  What is this invisible radiant energy now known as?
# 1423  What happened to most of Tesla's work from this time?
# 1424  What type of image was Tesla thought to have accidentally taken a week prior to the announcement of its discovery?
# 1425  Who was Tesla trying to photograph when he accidentally took the X-Ray image?
# 1426  What did Tesla begin to research in March 1896?
# 1427  when did tesla begin researching x-ray imaging?
# 1428  What is another term for x-ray imaging?
# 1429  What did Tesla design several experimental setups to produce?
# 1430  What did Tesla's device work from the output of?
# 1431  When did Tesla start deliberately experimenting with X-ray imaging?
# 1432  What powered Tesla's high energy terminal vacuum tube?
# 1433  What were X-rays known as at the time?
# 1434  What did tesla incorrectly believe about x-rays?
# 1435  what did tesla attribute skin damage to?
# 1436  what did Tesla think nitrous acid contributed to?
# 1437  what did tesla note the hazards of working with?
# 1438  where do plasma waves occur?
# 1439  At first what did Tesla think was the main cause of damage to skin cells when they were exposed to X-rays?
# 1440  What did Tesla mistakenly believe X-rays were?
# 1441  Where are longitudinal waves found?
# 1442  Where can Tesla's theories as to what caused the skin damage be found?
# 1443  Which engineer made the induction motor more efficient?
# 1444  In which year did Benjamin Lamme achieve success making the motor more efficient?
# 1445  Who called their system the "Tesla Polyphase System"?
# 1446  What was Tesla's device called?
# 1447  Who demonstrated the Egg of Columbus?
# 1448  When did the Herald Tribune publish its Tesla article?
# 1449  What did the particle do to Tesla?
# 1450  How did Tesla know he was being struck by the particle?
# 1451  What other projectiles did Tesla compare the electric particles to?
# 1452  What association did Tesla demonstrate his radio wave theories to?
# 1453  Which of Tesla's inventions was used in radio development?
# 1454  What Philadelphia institution did Tesla give a demonstration to?
# 1455  When did Tesla give a demonstration of his remote control boat?
# 1456  What was the boat called?
# 1457  Where was the boat demonstration given?
# 1458  What was the occasion for the boat demonstration?
# 1459  What type of animal did onlookers claim was piloting the boat?
# 1460  When did Tesla attain his electrical transmitter patent?
# 1461  Who first sent radio waves across the Atlantic?
# 1462  When was Marconi's radio demonstration?
# 1463  When were Tesla's patents restored?
# 1464  A decision made by what entity restored Tesla's patents?
# 1465  In what year did Tesla go to Colorado Springs?
# 1466  Where did he claim he would transport energy to?
# 1467  What date did Tesla begin his Colorado Springs experiments?
# 1468  What was the recorded length of the first spark?
# 1469  What kind of electricity was Tesla investigating?
# 1470  What sort of waves did he claim to observe?
# 1471  What was Tesla's idea regarding Earth?
# 1472  What natural phenomenon did Tesla create artificially?
# 1473  How big were his artificial bolts?
# 1474  From what distance could the artificial thunder be heard.
# 1475  What happened to nearby light bulbs?
# 1476  What was notable about the butterflies?
# 1477  What did Tesla accidentally cause?
# 1478  What happened to the dynamos in the power station?
# 1479  What caused the dynamos to be burnt out?
# 1480  What did the sparks do to the insulation?
# 1481  To what did Tesla attribute the unknown signals his radio received?
# 1482  What planet did the reporters decide the signals were from?
# 1483  What magazine did Tesla talk to about the strange signals?
# 1484  What is another possible explanation for the source of the signals?
# 1485  When did Marconi transmit similar signals to those Tesla received?
# 1486  How much money did John Jacob Astor IV provide Tesla with?
# 1487  What did Astor expect the money be used for?
# 1488  What did Tesla spend Astor's money on?
# 1489  When did Astor provide the money?
# 1490  When did Tesla depart from Colorado Springs?
# 1491  What happened to his lab?
# 1492  When was his lab destroyed?
# 1493  What happened to the things inside the lab after it was torn down?
# 1494  What did Tesla establish following his Colorado experiments?
# 1495  What kind of facility was Wardenclyffe?
# 1496  Where was Wardenclyffe located?
# 1497  Who did Tesla try to get money from?
# 1498  On what did Tesla blame for the loss of the initial money?
# 1499  How did Morgan react to the request?

# %%
'''Create tokenized dataset'''

tok_qg_data = tokenize_data(qg_data['input_text'], qg_data['question'],
                            tokenizer, tokenize_fn=data_utils.tokenize_fn, entity_masking=entity_masking)
if entity_masking:
    display(pandas.DataFrame({**tok_qg_data, **{'tokens_to_tags': qg_data['tokens_to_tags'][:10]}})[:100])
else:
    display(pandas.DataFrame(tok_qg_data))
# Out:
# 10000
#                                                                                                                                                                                                                                                                                                                                                                                                                                                  input_text  \
# 0      The ĠAmerican ĠFootball ĠConference Ġ( A FC ) Ġchampion <ANSWER> ĠDenver ĠBroncos </ANSWER> Ġdefeated Ġthe ĠNational ĠFootball ĠConference Ġ( N FC ) Ġchampion ĠCarolina ĠPanthers Ġ24 âĢĵ 10 Ġto Ġearn Ġtheir Ġthird ĠSuper ĠBowl Ġtitle .
# 1      The ĠAmerican ĠFootball ĠConference Ġ( A FC ) Ġchampion ĠDenver ĠBroncos Ġdefeated Ġthe ĠNational ĠFootball ĠConference Ġ( N FC ) Ġchampion <ANSWER> ĠCarolina ĠPanthers </ANSWER> Ġ24 âĢĵ 10 Ġto Ġearn Ġtheir Ġthird ĠSuper ĠBowl Ġtitle .
# 2      The Ġgame Ġwas Ġplayed Ġon ĠFebruary Ġ7 , Ġ2016 , Ġat <ANSWER> ĠLevi 's ĠStadium Ġin Ġthe ĠSan ĠFrancisco ĠBay ĠArea Ġat ĠSanta ĠClara , ĠCalifornia . </ANSWER>
# 3      The ĠAmerican ĠFootball ĠConference Ġ( A FC ) Ġchampion <ANSWER> ĠDenver ĠBroncos </ANSWER> Ġdefeated Ġthe ĠNational ĠFootball ĠConference Ġ( N FC ) Ġchampion ĠCarolina ĠPanthers Ġ24 âĢĵ 10 Ġto Ġearn Ġtheir Ġthird ĠSuper ĠBowl Ġtitle .
# 4      As Ġthis Ġwas Ġthe Ġ50 th ĠSuper ĠBowl , Ġthe Ġleague Ġemphasized Ġthe Ġ" <ANSWER> Ġgold </ANSWER> en Ġanniversary " Ġwith Ġvarious Ġgold - themed Ġinitiatives , Ġas Ġwell Ġas Ġtemporarily Ġsuspending Ġthe Ġtradition Ġof Ġnaming Ġeach ĠSuper ĠBowl Ġgame Ġwith ĠRoman Ġnumer als Ġ( under Ġwhich Ġthe Ġgame Ġwould Ġhave Ġbeen Ġknown Ġas Ġ" Super ĠBowl ĠL "), Ġso Ġthat Ġthe Ġlogo Ġcould Ġprominently Ġfeature Ġthe ĠArabic Ġnumer als Ġ50 .
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# 14906  " A Ġtotal Ġof <ANSWER> Ġseven </ANSWER> Ġdied Ġon Ġour Ġproperty ," ĠO ' Connor Ġtold ĠCNN .
# 14907  Te ams Ġare Ġtrying Ġto Ġfigure Ġout Ġwhat Ġhappened Ġat Ġthe <ANSWER> ĠInternational ĠPolo ĠClub ĠPalm ĠBeach Ġin ĠFlorida . </ANSWER>
# 14908  Four teen Ġthorough bred Ġhorses Ġdropped Ġdead Ġin Ġa Ġmysterious Ġscene ĠSunday Ġbefore Ġa Ġpol o Ġmatch Ġnear <ANSWER> ĠWest ĠPalm ĠBeach , ĠFlorida , </ANSWER> Ġofficials Ġsaid .
# 14909  The Ġcause Ġof Ġthe Ġdeaths <ANSWER> Ġhas Ġnot Ġbeen Ġdetermined , </ANSWER> Ġand Ġne cro ps ies Ġand Ġblood Ġtests Ġwere Ġunderway , Ġhe Ġsaid .
# 14910  <ANSWER> ĠFour teen </ANSWER> Ġthorough bred Ġhorses Ġdropped Ġdead Ġin Ġa Ġmysterious Ġscene ĠSunday Ġbefore Ġa Ġpol o Ġmatch Ġnear ĠWest ĠPalm ĠBeach , ĠFlorida , Ġofficials Ġsaid .
#
#                                                                                      question
# 0      Which ĠNFL Ġteam Ġrepresented Ġthe ĠAFC Ġat ĠSuper ĠBowl Ġ50 ?
# 1      Which ĠNFL Ġteam Ġrepresented Ġthe ĠNFC Ġat ĠSuper ĠBowl Ġ50 ?
# 2      Where Ġdid ĠSuper ĠBowl Ġ50 Ġtake Ġplace ?
# 3      Which ĠNFL Ġteam Ġwon ĠSuper ĠBowl Ġ50 ?
# 4      What Ġcolor Ġwas Ġused Ġto Ġemphasize Ġthe Ġ50 th Ġanniversary Ġof Ġthe ĠSuper ĠBowl ?
# ...                                                                                       ...
# 14906  How Ġmany Ġhorses Ġdied ?
# 14907  Where Ġwere Ġthe Ġraces Ġheld ?
# 14908  Where Ġwas Ġthe Ġmatch Ġset ?
# 14909  What Ġwas Ġthe Ġreason Ġthat Ġhorses Ġdie ?
# 14910  How Ġmany Ġhors ed Ġdied ?
#
# [14911 rows x 2 columns]

# %%
#Sanity check to ensure tokenization works 

data_utils.detokenize_fn(tokenizer, tok_qg_data['input_text'][-11].split(" "))
# Out:
# "NASA launches a rocket from California's Vandenberg Air Force Base on <ANSWER> Tuesday. </ANSWER>"

# %%
'''Save the tokenized dataset'''

data_dir = "/home/mroemmele/question_generation/squad_newsqa_gpt2_tok_data/"

if not os.path.isdir(data_dir):
    os.mkdir(data_dir)

if not os.path.isdir(os.path.join(data_dir, partition)):
    os.mkdir(os.path.join(data_dir, partition))
    
with open(os.path.join(data_dir, partition, 'answer_sents.txt'), 'w') as f:
    f.write("\n".join(tok_qg_data['input_text']))

with open(os.path.join(data_dir, partition, 'questions.txt'), 'w') as f:
    f.write("\n".join(tok_qg_data['question']))

# %%
partition
# Out:
# 'test'
