# %%
import json
import os
import pandas
import pickle
import spacy
import importlib
import re
from collections import defaultdict
from nltk import sent_tokenize

import data_utils
importlib.reload(data_utils)

pandas.set_option('display.max_colwidth', -1)
pandas.set_option('display.max_rows', 500)

# %% [markdown]
# ## Create SQuAD dataset with annotated answers in paragraphs and answer sents

# %%
'''Function that returns SQuAD text-question items with answer annotations in paragraphs/answer sentences'''

def make_squad_qg_dataset(squad_data):
    #import pdb;pdb.set_trace()
    wrangled_squad_data = {'article_id': [],
                           'paragraph': [],
                           'answer_sent': [],
                           'question': [],
                           'answer': [],
                          }

    for article_idx, article in enumerate(squad_data['data']):
        for paragraph in article['paragraphs']:
            paragraph_sents = data_utils.segment_sents(paragraph['context'])
            for qa in paragraph['qas']:
                question_text = qa['question']
                all_answers = [answer['text'] for answer in qa['answers']]
                #import pdb;pdb.set_trace()
                longest_answer_idx, longest_answer = sorted(enumerate(all_answers), 
                                            key=lambda answer:len(answer[1]), reverse=True)[0]
                # In case of multiple answers for a given question, just annotate longest answer span
                answer = qa['answers'][longest_answer_idx]
                answer_text = answer['text']
                answer_char_start = answer['answer_start']
                answer_char_end = answer_char_start + len(answer_text)
                for sent_idx in range(len(paragraph_sents['sents'])):
                    sent_char_start = paragraph_sents['sent_char_start_idxs'][sent_idx]
                    if sent_idx + 1 == len(paragraph_sents['sents']):
                        #import pdb;pdb.set_trace()
                        sent_char_end = (paragraph_sents['sent_char_start_idxs'][-1] + 
                                         len(paragraph_sents['sents'][-1]))
                        if sent_char_end != len(paragraph['context']):
                            import pdb;pdb.set_trace()
                    else:
                        sent_char_end = paragraph_sents['sent_char_start_idxs'][sent_idx + 1]
                    if sent_char_start <= answer_char_start < sent_char_end:
                        while answer_char_end > sent_char_end:
                            # Answer spans multiple sentences, which is probably a segmentation failure;
                            # just append next sentence to this one as answer sentence
                            try:
#                                     import pdb;pdb.set_trace()
                                paragraph_sents['sents'][sent_idx] = (paragraph_sents['sents'][sent_idx] + 
                                                                    paragraph_sents['sents'][sent_idx + 1])
                                paragraph_sents['sents'].pop(sent_idx + 1)
                                paragraph_sents['sent_char_start_idxs'].pop(sent_idx + 1)
                                if sent_idx + 1 == len(paragraph_sents['sents']):
                                    sent_char_end = len(paragraph['context'])
                                else:
                                    sent_char_end = paragraph_sents['sent_char_start_idxs'][sent_idx + 1]
                            except:
                                import pdb;pdb.set_trace()
                        break
                answer_sent_text = paragraph_sents['sents'][sent_idx]
                #insert answer tokens into sentence
                answer_start_insert_idx = answer_char_start - sent_char_start
                answer_end_insert_idx = answer_char_end - sent_char_start
                answer_sent_text = (answer_sent_text[:answer_start_insert_idx] + "<ANSWER> "
                               + answer_sent_text[answer_start_insert_idx:])
                answer_sent_text = (answer_sent_text[:answer_end_insert_idx + len("<ANSWER> ")]
                               + " </ANSWER>" +
                               answer_sent_text[answer_end_insert_idx + len("<ANSWER> "):])
                paragraph_sents_with_answer = paragraph_sents['sents'][:]
                paragraph_sents_with_answer[sent_idx] = answer_sent_text
                paragraph_text = "".join(paragraph_sents_with_answer)

                wrangled_squad_data['article_id'].append(article_idx)
                #For some reason, there are line breaks in a few of the texts in the test set, be sure to replace
                wrangled_squad_data['paragraph'].append(paragraph_text.replace("\n", ""))
                wrangled_squad_data['answer_sent'].append(answer_sent_text.replace("\n", ""))
                wrangled_squad_data['question'].append(question_text.replace("\n", ""))
                wrangled_squad_data['answer'].append("\t".join([answer.replace("\n", "")
                                                                for answer in list(set(all_answers))]))
#                     wrangled_squad_data['all_answers'].append("\t".join([answer.replace("\n", "") 
#                                                                          for answer in list(all_answers)]))
            #print("paragraph done")
        if article_idx and article_idx % 10 == 0:
            print(article_idx)
            #break
    return wrangled_squad_data

# %%
'''Load original SQuAD data, selecting partition (train or valid)'''

partition = 'test'
assert partition in ('train', 'test')
with open("/home/mroemmele/CoreNLP/others/reading_comprehension/v1/{}-v1.1.json".format(
        'dev' if partition == 'test' else 'train')) as f:
    squad_data = json.load(f)

# %%
#pandas.DataFrame(qg_data)[:10]

# %%
'''Make the dataset'''

qg_data = make_squad_qg_dataset(squad_data)
pandas.DataFrame(qg_data)[-100:]
# Out:
# 10
# 20
# 30
# 40
#        article_id  \
# 10470  47
# 10471  47
# 10472  47
# 10473  47
# 10474  47
# 10475  47
# 10476  47
# 10477  47
# 10478  47
# 10479  47
# 10480  47
# 10481  47
# 10482  47
# 10483  47
# 10484  47
# 10485  47
# 10486  47
# 10487  47
# 10488  47
# 10489  47
# 10490  47
# 10491  47
# 10492  47
# 10493  47
# 10494  47
# 10495  47
# 10496  47
# 10497  47
# 10498  47
# 10499  47
# 10500  47
# 10501  47
# 10502  47
# 10503  47
# 10504  47
# 10505  47
# 10506  47
# 10507  47
# 10508  47
# 10509  47
# 10510  47
# 10511  47
# 10512  47
# 10513  47
# 10514  47
# 10515  47
# 10516  47
# 10517  47
# 10518  47
# 10519  47
# 10520  47
# 10521  47
# 10522  47
# 10523  47
# 10524  47
# 10525  47
# 10526  47
# 10527  47
# 10528  47
# 10529  47
# 10530  47
# 10531  47
# 10532  47
# 10533  47
# 10534  47
# 10535  47
# 10536  47
# 10537  47
# 10538  47
# 10539  47
# 10540  47
# 10541  47
# 10542  47
# 10543  47
# 10544  47
# 10545  47
# 10546  47
# 10547  47
# 10548  47
# 10549  47
# 10550  47
# 10551  47
# 10552  47
# 10553  47
# 10554  47
# 10555  47
# 10556  47
# 10557  47
# 10558  47
# 10559  47
# 10560  47
# 10561  47
# 10562  47
# 10563  47
# 10564  47
# 10565  47
# 10566  47
# 10567  47
# 10568  47
# 10569  47
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                paragraph  \
# 10470  The development of fundamental theories for forces proceeded along the lines of unification of disparate ideas. For example, Isaac Newton unified the force responsible for objects falling at the surface of the Earth with the force responsible for the orbits of celestial mechanics in his universal theory of gravitation. Michael Faraday and James Clerk Maxwell demonstrated that electric and magnetic forces were unified through one consistent theory of electromagnetism. In the 20th century, the development of quantum mechanics led to a modern understanding that the first three fundamental forces (all except gravity) are manifestations of matter (fermions) interacting by exchanging virtual particles called gauge bosons. This standard model of particle physics posits a similarity between the forces and led scientists to predict the unification of the weak and electromagnetic forces in electroweak theory subsequently confirmed by observation. The complete formulation of the standard model predicts an as yet unobserved Higgs mechanism, but observations such as neutrino oscillations indicate that the standard model is incomplete. A Grand Unified Theory allowing for the combination of the electroweak interaction with the strong force is held out as a possibility with candidate theories such as supersymmetry proposed to accommodate some of the outstanding unsolved problems in physics. Physicists are still attempting to develop <ANSWER> self-consistent unification models that would combine all four fundamental interactions </ANSWER> into a theory of everything. Einstein tried and failed at this endeavor, but currently the most popular approach to answering this question is string theory.:212–219
# 10471  What we now call gravity was not identified as a universal force until the work of <ANSWER> Isaac Newton </ANSWER>. Before Newton, the tendency for objects to fall towards the Earth was not understood to be related to the motions of celestial objects. Galileo was instrumental in describing the characteristics of falling objects by determining that the acceleration of every object in free-fall was constant and independent of the mass of the object. Today, this acceleration due to gravity towards the surface of the Earth is usually designated as  and has a magnitude of about 9.81 meters per second squared (this measurement is taken from sea level and may vary depending on location), and points toward the center of the Earth. This observation means that the force of gravity on an object at the Earth's surface is directly proportional to the object's mass. Thus an object that has a mass of  will experience a force:
# 10472  What we now call gravity was not identified as a universal force until the work of Isaac Newton. Before Newton, the tendency for objects to fall towards the Earth was not understood to be related to the motions of celestial objects. <ANSWER> Galileo </ANSWER> was instrumental in describing the characteristics of falling objects by determining that the acceleration of every object in free-fall was constant and independent of the mass of the object. Today, this acceleration due to gravity towards the surface of the Earth is usually designated as  and has a magnitude of about 9.81 meters per second squared (this measurement is taken from sea level and may vary depending on location), and points toward the center of the Earth. This observation means that the force of gravity on an object at the Earth's surface is directly proportional to the object's mass. Thus an object that has a mass of  will experience a force:
# 10473  What we now call gravity was not identified as a universal force until the work of Isaac Newton. Before Newton, the tendency for objects to fall towards the Earth was not understood to be related to the motions of celestial objects. Galileo was instrumental in describing the characteristics of falling objects by determining that the acceleration of every object in free-fall was constant and independent of the mass of the object. Today, this acceleration due to gravity towards the surface of the Earth is usually designated as  and has a magnitude of <ANSWER> about 9.81 meters per second squared </ANSWER> (this measurement is taken from sea level and may vary depending on location), and points toward the center of the Earth. This observation means that the force of gravity on an object at the Earth's surface is directly proportional to the object's mass. Thus an object that has a mass of  will experience a force:
# 10474  What we now call gravity was not identified as a universal force until the work of Isaac Newton. Before Newton, the tendency for objects to fall towards the Earth was not understood to be related to the motions of celestial objects. Galileo was instrumental in describing the characteristics of falling objects by determining that the acceleration of every object in free-fall was constant and independent of the mass of the object. Today, this acceleration due to gravity towards the surface of the Earth is usually designated as  and has a magnitude of about 9.81 meters per second squared (this measurement is taken <ANSWER> from sea level </ANSWER> and may vary depending on location), and points toward the center of the Earth. This observation means that the force of gravity on an object at the Earth's surface is directly proportional to the object's mass. Thus an object that has a mass of  will experience a force:
# 10475  What we now call gravity was not identified as a universal force until the work of Isaac Newton. Before Newton, the tendency for objects to fall towards the Earth was not understood to be related to the motions of celestial objects. Galileo was instrumental in describing the characteristics of falling objects by determining that the acceleration of every object in free-fall was constant and independent of the mass of the object. Today, this acceleration due to gravity towards the surface of the Earth is usually designated as  and has a magnitude of about 9.81 meters per second squared (this measurement is taken from sea level and may vary depending on location), and points toward the center of the Earth. This observation means that <ANSWER> the force of gravity on an object </ANSWER> at the Earth's surface is directly proportional to the object's mass. Thus an object that has a mass of  will experience a force:
# 10476  Newton came to realize that the effects of gravity might be observed in different ways <ANSWER> at larger distances. </ANSWER> In particular, Newton determined that the acceleration of the Moon around the Earth could be ascribed to the same force of gravity if the acceleration due to gravity decreased as an inverse square law. Further, Newton realized that the acceleration due to gravity is proportional to the mass of the attracting body. Combining these ideas gives a formula that relates the mass () and the radius () of the Earth to the gravitational acceleration:
# 10477  Newton came to realize that the effects of gravity might be observed in different ways at larger distances. In particular, Newton determined that the acceleration of the Moon around the Earth could be ascribed to <ANSWER> the same force of gravity if the acceleration due to gravity decreased as an inverse square law. </ANSWER> Further, Newton realized that the acceleration due to gravity is proportional to the mass of the attracting body. Combining these ideas gives a formula that relates the mass () and the radius () of the Earth to the gravitational acceleration:
# 10478  Newton came to realize that the effects of gravity might be observed in different ways at larger distances. In particular, Newton determined that the acceleration of the Moon around the Earth could be ascribed to the same force of gravity if the acceleration due to gravity decreased as an inverse square law. Further, Newton realized that the acceleration due to gravity is proportional to <ANSWER> the mass of the attracting body </ANSWER>. Combining these ideas gives a formula that relates the mass () and the radius () of the Earth to the gravitational acceleration:
# 10479  Newton came to realize that the effects of gravity might be observed in different ways at larger distances. In particular, Newton determined that the acceleration of the Moon around the Earth could be ascribed to the same force of gravity if the acceleration due to gravity decreased as an inverse square law. Further, Newton realized that the acceleration due to gravity is proportional to the mass of the attracting body. Combining these ideas gives a formula that relates the mass () and <ANSWER> the radius () of the Earth </ANSWER> to the gravitational acceleration:
# 10480  In this equation, a dimensional constant  is used to describe the relative strength of gravity. This constant has come to be known as <ANSWER> Newton's Universal Gravitation Constant, </ANSWER> though its value was unknown in Newton's lifetime. Not until 1798 was Henry Cavendish able to make the first measurement of  using a torsion balance; this was widely reported in the press as a measurement of the mass of the Earth since knowing  could allow one to solve for the Earth's mass given the above equation. Newton, however, realized that since all celestial bodies followed the same laws of motion, his law of gravity had to be universal. Succinctly stated, Newton's Law of Gravitation states that the force on a spherical object of mass  due to the gravitational pull of mass  is
# 10481  In this equation, a dimensional constant  is used to describe the relative strength of gravity. This constant has come to be known as Newton's Universal Gravitation Constant, though its value was unknown in Newton's lifetime. Not until 1798 was <ANSWER> Henry Cavendish </ANSWER> able to make the first measurement of  using a torsion balance; this was widely reported in the press as a measurement of the mass of the Earth since knowing  could allow one to solve for the Earth's mass given the above equation. Newton, however, realized that since all celestial bodies followed the same laws of motion, his law of gravity had to be universal. Succinctly stated, Newton's Law of Gravitation states that the force on a spherical object of mass  due to the gravitational pull of mass  is
# 10482  In this equation, a dimensional constant  is used to describe the relative strength of gravity. This constant has come to be known as Newton's Universal Gravitation Constant, though its value was unknown in Newton's lifetime. Not until <ANSWER> 1798 </ANSWER> was Henry Cavendish able to make the first measurement of  using a torsion balance; this was widely reported in the press as a measurement of the mass of the Earth since knowing  could allow one to solve for the Earth's mass given the above equation. Newton, however, realized that since all celestial bodies followed the same laws of motion, his law of gravity had to be universal. Succinctly stated, Newton's Law of Gravitation states that the force on a spherical object of mass  due to the gravitational pull of mass  is
# 10483  In this equation, a dimensional constant  is used to describe the relative strength of gravity. This constant has come to be known as Newton's Universal Gravitation Constant, though its value was unknown in Newton's lifetime. Not until 1798 was Henry Cavendish able to make the first measurement of  using a torsion balance; this was widely reported in the press as a measurement of the mass of the Earth since knowing  could allow one to solve for the Earth's mass given the above equation. <ANSWER> Newton </ANSWER>, however, realized that since all celestial bodies followed the same laws of motion, his law of gravity had to be universal. Succinctly stated, Newton's Law of Gravitation states that the force on a spherical object of mass  due to the gravitational pull of mass  is
# 10484  It was only the orbit of the planet <ANSWER> Mercury </ANSWER> that Newton's Law of Gravitation seemed not to fully explain. Some astrophysicists predicted the existence of another planet (Vulcan) that would explain the discrepancies; however, despite some early indications, no such planet could be found. When Albert Einstein formulated his theory of general relativity (GR) he turned his attention to the problem of Mercury's orbit and found that his theory added a correction, which could account for the discrepancy. This was the first time that Newton's Theory of Gravity had been shown to be less correct than an alternative.
# 10485  It was only the orbit of the planet Mercury that Newton's Law of Gravitation seemed not to fully explain. Some astrophysicists predicted the existence of another planet (<ANSWER> Vulcan </ANSWER>) that would explain the discrepancies; however, despite some early indications, no such planet could be found. When Albert Einstein formulated his theory of general relativity (GR) he turned his attention to the problem of Mercury's orbit and found that his theory added a correction, which could account for the discrepancy. This was the first time that Newton's Theory of Gravity had been shown to be less correct than an alternative.
# 10486  It was only the orbit of the planet Mercury that Newton's Law of Gravitation seemed not to fully explain. Some astrophysicists predicted the existence of another planet (Vulcan) that would explain the discrepancies; however, despite some early indications, no such planet could be found. When Albert Einstein formulated his <ANSWER> theory of general relativity (GR) </ANSWER> he turned his attention to the problem of Mercury's orbit and found that his theory added a correction, which could account for the discrepancy. This was the first time that Newton's Theory of Gravity had been shown to be less correct than an alternative.
# 10487  It was only the orbit of the planet Mercury that Newton's Law of Gravitation seemed not to fully explain. Some astrophysicists predicted the existence of another planet (Vulcan) that would explain the discrepancies; however, despite some early indications, no such planet could be found. When <ANSWER> Albert Einstein </ANSWER> formulated his theory of general relativity (GR) he turned his attention to the problem of Mercury's orbit and found that his theory added a correction, which could account for the discrepancy. This was the first time that Newton's Theory of Gravity had been shown to be less correct than an alternative.
# 10488  It was only the orbit of the planet Mercury that Newton's Law of Gravitation seemed not to fully explain. Some astrophysicists predicted the existence of another planet (Vulcan) that would explain the discrepancies; however, despite some early indications, no such planet could be found. When <ANSWER> Albert Einstein </ANSWER> formulated his theory of general relativity (GR) he turned his attention to the problem of Mercury's orbit and found that his theory added a correction, which could account for the discrepancy. This was the first time that Newton's Theory of Gravity had been shown to be less correct than an alternative.
# 10489  Since then, and so far, <ANSWER> general relativity </ANSWER> has been acknowledged as the theory that best explains gravity. In GR, gravitation is not viewed as a force, but rather, objects moving freely in gravitational fields travel under their own inertia in straight lines through curved space-time – defined as the shortest space-time path between two space-time events. From the perspective of the object, all motion occurs as if there were no gravitation whatsoever. It is only when observing the motion in a global sense that the curvature of space-time can be observed and the force is inferred from the object's curved path. Thus, the straight line path in space-time is seen as a curved line in space, and it is called the ballistic trajectory of the object. For example, a basketball thrown from the ground moves in a parabola, as it is in a uniform gravitational field. Its space-time trajectory (when the extra ct dimension is added) is almost a straight line, slightly curved (with the radius of curvature of the order of few light-years). The time derivative of the changing momentum of the object is what we label as "gravitational force".
# 10490  Since then, and so far, general relativity has been acknowledged as the theory that best explains gravity. In GR, gravitation is not viewed as a force, but rather, objects moving freely in gravitational fields travel under their own inertia in straight lines through curved space-time – defined as <ANSWER> the shortest space-time path between two space-time events. </ANSWER> From the perspective of the object, all motion occurs as if there were no gravitation whatsoever. It is only when observing the motion in a global sense that the curvature of space-time can be observed and the force is inferred from the object's curved path. Thus, the straight line path in space-time is seen as a curved line in space, and it is called the ballistic trajectory of the object. For example, a basketball thrown from the ground moves in a parabola, as it is in a uniform gravitational field. Its space-time trajectory (when the extra ct dimension is added) is almost a straight line, slightly curved (with the radius of curvature of the order of few light-years). The time derivative of the changing momentum of the object is what we label as "gravitational force".
# 10491  Since then, and so far, general relativity has been acknowledged as the theory that best explains gravity. In GR, gravitation is not viewed as a force, but rather, objects moving freely in gravitational fields travel under their own inertia in straight lines through curved space-time – defined as the shortest space-time path between two space-time events. From the perspective of the object, all motion occurs as if there were no gravitation whatsoever. It is only when observing the motion in a global sense that the curvature of space-time can be observed and the force is inferred from the object's curved path. Thus, the straight line path in space-time is seen as a curved line in space, and it is called the ballistic trajectory of the object. For example, a basketball thrown from the ground moves in a parabola, as it is in a uniform gravitational field. Its space-time trajectory (when the extra ct dimension is added) is almost a straight line, slightly curved (with the radius of curvature of the order of few light-years). The time derivative of the changing momentum of the object is what we label as "<ANSWER> gravitational force </ANSWER>".
# 10492  Since then, and so far, general relativity has been acknowledged as the theory that best explains gravity. In GR, gravitation is not viewed as a force, but rather, objects moving freely in gravitational fields travel under their own inertia in straight lines through curved space-time – defined as the shortest space-time path between two space-time events. From <ANSWER> the perspective of the object </ANSWER>, all motion occurs as if there were no gravitation whatsoever. It is only when observing the motion in a global sense that the curvature of space-time can be observed and the force is inferred from the object's curved path. Thus, the straight line path in space-time is seen as a curved line in space, and it is called the ballistic trajectory of the object. For example, a basketball thrown from the ground moves in a parabola, as it is in a uniform gravitational field. Its space-time trajectory (when the extra ct dimension is added) is almost a straight line, slightly curved (with the radius of curvature of the order of few light-years). The time derivative of the changing momentum of the object is what we label as "gravitational force".
# 10493  Through combining the definition of <ANSWER> electric current </ANSWER> as the time rate of change of electric charge, a rule of vector multiplication called Lorentz's Law describes the force on a charge moving in a magnetic field. The connection between electricity and magnetism allows for the description of a unified electromagnetic force that acts on a charge. This force can be written as a sum of the electrostatic force (due to the electric field) and the magnetic force (due to the magnetic field). Fully stated, this is the law:
# 10494  Through combining the definition of electric current as the time rate of change of electric charge, a rule of vector multiplication called Lorentz's Law describes the force on a charge moving in a magnetic field. The connection between electricity and magnetism allows for the description of a <ANSWER> unified electromagnetic force </ANSWER> that acts on a charge. This force can be written as a sum of the electrostatic force (due to the electric field) and the magnetic force (due to the magnetic field). Fully stated, this is the law:
# ...
# 10513  energy
# 10514  macroscopically as a structural force\ta structural force\tas a structural force
# 10515  elementary particles
# 10516  a residual of the force\tresidual of the force\tnucleons in atomic nuclei
# 10517  nuclear force\tnuclear force.\tnuclear
# 10518  as gluons
# 10519  color confinement
# 10520  weak force
# 10521  beta decay (of neutrons in atomic nuclei)\tbeta decay
# 10522  radioactivity
# 10523  1013
# 10524  1015 kelvins\tapproximately 1015 kelvins\tin excess of approximately 1015 kelvins
# 10525  normal force
# 10526  Pauli repulsion
# 10527  fermionic nature of electrons
# 10528  normal force\tnormal
# 10529  ideal strings that are massless\tideal strings that are massless, frictionless, unbreakable, and unstretchable\tideal strings
# 10530  ideal pulleys
# 10531  instantaneously in action-reaction pairs\taction-reaction pairs\tin action-reaction pairs
# 10532  conservation of mechanical energy\ttension force on a load can be multiplied\tthe tension force on a load can be multiplied
# 10533  connecting the same string multiple times to the same object through the use of a set-up that uses movable pulleys\tmovable pulleys\tconnecting the same string multiple times to the same object through the use of a set-up that uses movable pulleys,\tevery string
# 10534  idealized point particles rather than three-dimensional objects\tidealized point particles
# 10535  three-dimensional objects
# 10536  extended
# 10537  other parts of an object\tother parts
# 10538  extended structure\textended structure and forces that act on one part of an object might affect other parts of an object
# 10539  The stress tensor\tdeformations\tstress tensor
# 10540  pressure terms\tpressure terms associated with forces that act normal to the cross-sectional area (the matrix diagonals of the tensor) as well as shear terms\tstress tensor
# 10541  pressure terms\tmatrix diagonals of the tensor)
# 10542  This formalism\tformalism\tthe relevant cross-sectional area for the volume for which the stress-tensor is being calculated
# 10543  rotational inertia\trotational equivalent for position\tangle is the rotational equivalent for position\trotation
# 10544  an unbalanced torque\tunbalanced torque
# 10545  Newton's Second Law of Motion
# 10546  directed toward the center of the curving path\tthe center of the curving path\tcenter of the curving path.\ttoward the center of the curving path
# 10547  perpendicular
# 10548  unbalanced centripetal force\tcentripetal
# 10549  radial (centripetal) force\tradial
# 10550  tangential force
# 10551  kinetic
# 10552  potential
# 10553  net mechanical energy
# 10554  difference in potential energy\tthe difference in potential energy between two different locations in space\tthe difference in potential energy
# 10555  artifact of the potential field\tartifact\tan artifact
# 10556  forces\tforces as being due to gradient of potentials
# 10557  gradient of potentials.\tmacrophysical considerations that yield forces as arising from a macroscopic statistical average of microstates\tgradient of potentials
# 10558  friction
# 10559  Nonconservative forces\tNonconservative\tNonconservative forces other than friction
# 10560  detailed treatment with statistical mechanics\tdetailed\tstatistical mechanics
# 10561  nonconservative forces\tinternal energies of the system
# 10562  nonconservative forces
# 10563  Second law of thermodynamics\tSecond\tSecond law
# 10564  nonconservative forces
# 10565  kilogram-force (kgf)\tpound-force\tkilogram-force\tthe kilogram-force (
# 10566  kilopond
# 10567  metric slug\tthe metric slug\tslug
# 10568  kip
# 10569  sthène

# %%
'''Save the dataset'''
data_dir = "/home/mroemmele/question_generation/squad_untok_data/"

if not os.path.isdir(os.path.join(data_dir, partition)):
    os.mkdir(os.path.join(data_dir, partition))
       
with open(os.path.join(data_dir, partition, 'paragraphs.txt'), 'w') as f:
    f.write("\n".join(qg_data['paragraph']))
    
with open(os.path.join(data_dir, partition, 'answer_sents.txt'), 'w') as f:
    f.write("\n".join(qg_data['answer_sent']))

with open(os.path.join(data_dir, partition, 'questions.txt'), 'w') as f:
    f.write("\n".join(qg_data['question']))
    
with open(os.path.join(data_dir, partition, 'answers_only.txt'), 'w') as f:
    f.write("\n".join(qg_data['answer']))
    
# with open(os.path.join(data_dir, partition, 'all_answers_only.txt'), 'w') as f:
#     f.write("\n".join(qg_data['all_answers']))

# %% [markdown]
# ## Create entity-masked dataset

# %%
def mask_entities_in_data(input_texts, questions, ignore_tokens=["<ANSWER>", "</ANSWER>"]):
    masked_input_texts = []
    masked_questions = []
    tokens_to_tags = []
    for input_text, question in zip(input_texts, questions):
        item_tokens_to_tags = data_utils.get_tokens_to_tags(input_text + " " + question,
                                                            ignore_tokens)
        (masked_input_text, masked_question,
         item_tokens_to_tags) = data_utils.mask_entity_tokens(input_text,
                                                              question,
                                                              item_tokens_to_tags)
        masked_input_texts.append(masked_input_text)
        masked_questions.append(masked_question)
        tokens_to_tags.append(item_tokens_to_tags)
    return {'input_text': masked_input_texts, 
            'question': masked_questions, 
            'tokens_to_tags': tokens_to_tags}

# %%
'''Load SQuAD data'''

data_dir = "/home/mroemmele/question_generation/squad_untok_data/"
partition = 'test'
qg_data = {'input_text': [text.strip() for text in open(os.path.join(data_dir, partition, "answer_sents.txt"))],
          'question': [question.strip() for question in open(os.path.join(data_dir, partition, "questions.txt"))]}

# %%
'''Apply masking'''

masked_qg_data = mask_entities_in_data(qg_data['input_text'][:10], qg_data['question'][:10])
pandas.DataFrame(masked_qg_data)[-100:]
# Out:
#                                                                                                                                                                                                                        input_text  \
# 0  The <ORGANIZATION_1> (<ORGANIZATION_2>) champion <ANSWER> <ORGANIZATION_3> </ANSWER> defeated the <ORGANIZATION_4> (<ORGANIZATION_5>) champion <ORGANIZATION_6> <CARDINAL_1> to earn their <ORDINAL_1> <ORGANIZATION_7> title.
# 1  The <ORGANIZATION_1> (<ORGANIZATION_2>) champion <ANSWER> <ORGANIZATION_3> </ANSWER> defeated the <ORGANIZATION_4> (<ORGANIZATION_5>) champion <ORGANIZATION_6> <CARDINAL_1> to earn their <ORDINAL_1> <ORGANIZATION_7> title.
# 2  The <ORGANIZATION_1> (<ORGANIZATION_2>) champion <ANSWER> <ORGANIZATION_3> </ANSWER> defeated the <ORGANIZATION_4> (<ORGANIZATION_5>) champion <ORGANIZATION_6> <CARDINAL_1> to earn their <ORDINAL_1> <ORGANIZATION_7> title.
# 3  The <ORGANIZATION_1> (<ORGANIZATION_2>) champion <ORGANIZATION_3> defeated the <ORGANIZATION_4> (<ORGANIZATION_5>) champion <ANSWER> <ORGANIZATION_6> </ANSWER> <CARDINAL_1> to earn their <ORDINAL_1> <ORGANIZATION_7> title.
# 4  The <ORGANIZATION_1> (<ORGANIZATION_2>) champion <ORGANIZATION_3> defeated the <ORGANIZATION_4> (<ORGANIZATION_5>) champion <ANSWER> <ORGANIZATION_6> </ANSWER> <CARDINAL_1> to earn their <ORDINAL_1> <ORGANIZATION_7> title.
# 5  The <ORGANIZATION_1> (<ORGANIZATION_2>) champion <ORGANIZATION_3> defeated the <ORGANIZATION_4> (<ORGANIZATION_5>) champion <ANSWER> <ORGANIZATION_6> </ANSWER> <CARDINAL_1> to earn their <ORDINAL_1> <ORGANIZATION_7> title.
# 6  The game was played on <DATE_1>, at <LOCATION_1> in the <LOCATION_2> at <ANSWER> <LOCATION_3>, <LOCATION_4> </ANSWER>.
# 7  The game was played on <DATE_1>, at <ANSWER> <LOCATION_1> </ANSWER> in the <LOCATION_2> at <LOCATION_3>, <LOCATION_4>.
# 8  The game was played on <DATE_1>, at <ANSWER> <LOCATION_1> in the <LOCATION_2> at <LOCATION_3>, <LOCATION_4>. </ANSWER>
# 9  The <ORGANIZATION_1> (<ORGANIZATION_2>) champion <ANSWER> <ORGANIZATION_3> </ANSWER> defeated the <ORGANIZATION_4> (<ORGANIZATION_5>) champion <ORGANIZATION_6> <CARDINAL_1> to earn their <ORDINAL_1> <ORGANIZATION_7> title.
#
#                                                                                question  \
# 0  Which <ORGANIZATION_8> team represented the <ORGANIZATION_2> at <ORGANIZATION_7> 50?
# 1  Which <ORGANIZATION_8> team represented the <ORGANIZATION_2> at <ORGANIZATION_7> 50?
# 2  Which <ORGANIZATION_8> team represented the <ORGANIZATION_2> at <ORGANIZATION_7> 50?
# 3  Which <ORGANIZATION_8> team represented the <ORGANIZATION_5> at <ORGANIZATION_7> 50?
# 4  Which <ORGANIZATION_8> team represented the <ORGANIZATION_5> at <ORGANIZATION_7> 50?
# 5  Which <ORGANIZATION_8> team represented the <ORGANIZATION_5> at <ORGANIZATION_7> 50?
# 6  Where did <EVENT_1> take place?
# 7  Where did <EVENT_1> take place?
# 8  Where did <EVENT_1> take place?
# 9  Which <ORGANIZATION_8> team won <EVENT_1>?
#
#                                                                                                                                                                                                                                                                                                                                                                               tokens_to_tags
# 0  {'American Football Conference': '<ORGANIZATION_1>', 'AFC': '<ORGANIZATION_2>', 'Denver Broncos': '<ORGANIZATION_3>', 'National Football Conference': '<ORGANIZATION_4>', 'NFC': '<ORGANIZATION_5>', 'Carolina Panthers': '<ORGANIZATION_6>', '24–10': '<CARDINAL_1>', 'third': '<ORDINAL_1>', 'Super Bowl': '<ORGANIZATION_7>', 'NFL': '<ORGANIZATION_8>'}
# 1  {'American Football Conference': '<ORGANIZATION_1>', 'AFC': '<ORGANIZATION_2>', 'Denver Broncos': '<ORGANIZATION_3>', 'National Football Conference': '<ORGANIZATION_4>', 'NFC': '<ORGANIZATION_5>', 'Carolina Panthers': '<ORGANIZATION_6>', '24–10': '<CARDINAL_1>', 'third': '<ORDINAL_1>', 'Super Bowl': '<ORGANIZATION_7>', 'NFL': '<ORGANIZATION_8>'}
# 2  {'American Football Conference': '<ORGANIZATION_1>', 'AFC': '<ORGANIZATION_2>', 'Denver Broncos': '<ORGANIZATION_3>', 'National Football Conference': '<ORGANIZATION_4>', 'NFC': '<ORGANIZATION_5>', 'Carolina Panthers': '<ORGANIZATION_6>', '24–10': '<CARDINAL_1>', 'third': '<ORDINAL_1>', 'Super Bowl': '<ORGANIZATION_7>', 'NFL': '<ORGANIZATION_8>'}
# 3  {'American Football Conference': '<ORGANIZATION_1>', 'AFC': '<ORGANIZATION_2>', 'Denver Broncos': '<ORGANIZATION_3>', 'National Football Conference': '<ORGANIZATION_4>', 'NFC': '<ORGANIZATION_5>', 'Carolina Panthers': '<ORGANIZATION_6>', '24–10': '<CARDINAL_1>', 'third': '<ORDINAL_1>', 'Super Bowl': '<ORGANIZATION_7>', 'NFL': '<ORGANIZATION_8>'}
# 4  {'American Football Conference': '<ORGANIZATION_1>', 'AFC': '<ORGANIZATION_2>', 'Denver Broncos': '<ORGANIZATION_3>', 'National Football Conference': '<ORGANIZATION_4>', 'NFC': '<ORGANIZATION_5>', 'Carolina Panthers': '<ORGANIZATION_6>', '24–10': '<CARDINAL_1>', 'third': '<ORDINAL_1>', 'Super Bowl': '<ORGANIZATION_7>', 'NFL': '<ORGANIZATION_8>'}
# 5  {'American Football Conference': '<ORGANIZATION_1>', 'AFC': '<ORGANIZATION_2>', 'Denver Broncos': '<ORGANIZATION_3>', 'National Football Conference': '<ORGANIZATION_4>', 'NFC': '<ORGANIZATION_5>', 'Carolina Panthers': '<ORGANIZATION_6>', '24–10': '<CARDINAL_1>', 'third': '<ORDINAL_1>', 'Super Bowl': '<ORGANIZATION_7>', 'NFL': '<ORGANIZATION_8>'}
# 6  {'February 7, 2016': '<DATE_1>', 'Levi's Stadium': '<LOCATION_1>', 'San Francisco Bay Area': '<LOCATION_2>', 'Santa Clara': '<LOCATION_3>', 'California': '<LOCATION_4>', 'Super Bowl 50': '<EVENT_1>'}
# 7  {'February 7, 2016': '<DATE_1>', 'Levi's Stadium': '<LOCATION_1>', 'San Francisco Bay Area': '<LOCATION_2>', 'Santa Clara': '<LOCATION_3>', 'California': '<LOCATION_4>', 'Super Bowl 50': '<EVENT_1>'}
# 8  {'February 7, 2016': '<DATE_1>', 'Levi's Stadium': '<LOCATION_1>', 'San Francisco Bay Area': '<LOCATION_2>', 'Santa Clara': '<LOCATION_3>', 'California': '<LOCATION_4>', 'Super Bowl 50': '<EVENT_1>'}
# 9  {'American Football Conference': '<ORGANIZATION_1>', 'AFC': '<ORGANIZATION_2>', 'Denver Broncos': '<ORGANIZATION_3>', 'National Football Conference': '<ORGANIZATION_4>', 'NFC': '<ORGANIZATION_5>', 'Carolina Panthers': '<ORGANIZATION_6>', '24–10': '<CARDINAL_1>', 'third': '<ORDINAL_1>', 'Super Bowl': '<ORGANIZATION_7>', 'NFL': '<ORGANIZATION_8>', 'Super Bowl 50': '<EVENT_1>'}

# %%
'''Save the masked dataset'''

data_dir = "/home/mroemmele/question_generation/squad_entity_masked_data"

if not os.path.isdir(os.path.join(data_dir, partition)):
    os.mkdir(os.path.join(data_dir, partition))
    
with open(os.path.join(data_dir, partition, 'answer_sents.txt'), 'w') as f:
    f.write("\n".join(masked_qg_data['input_text']))

with open(os.path.join(data_dir, partition, 'questions.txt'), 'w') as f:
    f.write("\n".join(masked_qg_data['question']))
    
with open(os.path.join(data_dir, partition, 'tokens_to_tags.pkl'), 'wb') as f:
    pickle.dump(masked_qg_data['tokens_to_tags'], f)

# %% [markdown]
# ## Create tokenized dataset that can be used for training

# %%
def tokenize_data(input_texts, questions, tokenizer, tokenize_fn):
    # Add special character after answer/entity annotations so tokenizer will respect space
    tok_input_texts = []
    tok_questions = []
    for input_text, question in zip(input_texts, questions):
        tok_question = " ".join(tokenize_fn(tokenizer, question))
        tok_questions.append(tok_question)
        tok_input_text = " ".join(tokenize_fn(tokenizer, input_text))
        tok_input_texts.append(tok_input_text)
    return {'input_text': tok_input_texts,
            'question': tok_questions}

# %%
'''Load SQuAD data'''

data_dir = "/home/mroemmele/question_generation/squad_rule_generated_data/untok_data/"
partition = 'train'
qg_data = {'input_text': [text.strip() for text in open(os.path.join(data_dir, partition, "answer_sents.txt"))],
           'question': [question.strip() for question in open(os.path.join(data_dir, partition, "questions.txt"))],
           'tokens_to_tags': pickle.load(open(os.path.join(data_dir, partition, "tokens_to_tags.pkl"), 'rb'))}
          #}

# %%
'''Load tokenizer and define tokenization function'''

from transformers import GPT2Tokenizer, BertTokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
# Add special tokens for designating answers in squad texts
special_tokens = ["<ANSWER>", "</ANSWER>"]
# Add entity tags as special tokens (each tag indexed up to 100)
special_tokens.extend(["Ġ<{}".format(tag) for tag in data_utils.ENTITY_TAGS])
special_tokens.extend(["<{}".format(tag) for tag in data_utils.ENTITY_TAGS])
special_tokens.extend(["_{}>".format(num) for num in range(1,101)])
tokenizer.add_tokens(special_tokens)
#Save tokenizer vocab with special tokens added
tokenizer.save_pretrained("/home/mroemmele/question_generation/gpt2_tokenizer_vocab/")
# Out:
# I1113 19:27:10.912777 140299533100864 tokenization_utils.py:373] loading file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-vocab.json from cache at /home/mroemmele/.cache/torch/transformers/f2808208f9bec2320371a9f5f891c184ae0b674ef866b79c58177067d15732dd.1512018be4ba4e8726e41b9145129dc30651ea4fec86aa61f4b9f40bf94eac71
# I1113 19:27:10.914906 140299533100864 tokenization_utils.py:373] loading file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-merges.txt from cache at /home/mroemmele/.cache/torch/transformers/d629f792e430b3c76a1291bb2766b0a047e36fae0588f9dbc1ae51decdff691b.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda
# I1113 19:27:11.531922 140299533100864 tokenization_utils.py:517] Adding <ANSWER> to the vocabulary
# I1113 19:27:11.534209 140299533100864 tokenization_utils.py:517] Adding </ANSWER> to the vocabulary
# I1113 19:27:11.536138 140299533100864 tokenization_utils.py:517] Adding Ġ<PRODUCT to the vocabulary
# I1113 19:27:11.537971 140299533100864 tokenization_utils.py:517] Adding Ġ<TIME to the vocabulary
# I1113 19:27:11.539833 140299533100864 tokenization_utils.py:517] Adding Ġ<QUANTITY to the vocabulary
# I1113 19:27:11.541676 140299533100864 tokenization_utils.py:517] Adding Ġ<EVENT to the vocabulary
# I1113 19:27:11.543485 140299533100864 tokenization_utils.py:517] Adding Ġ<DATE to the vocabulary
# I1113 19:27:11.545354 140299533100864 tokenization_utils.py:517] Adding Ġ<CARDINAL to the vocabulary
# I1113 19:27:11.547177 140299533100864 tokenization_utils.py:517] Adding Ġ<MONEY to the vocabulary
# I1113 19:27:11.549003 140299533100864 tokenization_utils.py:517] Adding Ġ<LAW to the vocabulary
# I1113 19:27:11.550806 140299533100864 tokenization_utils.py:517] Adding Ġ<WORK_OF_ART to the vocabulary
# I1113 19:27:11.552627 140299533100864 tokenization_utils.py:517] Adding Ġ<PERSON to the vocabulary
# I1113 19:27:11.554435 140299533100864 tokenization_utils.py:517] Adding Ġ<NORP to the vocabulary
# I1113 19:27:11.556225 140299533100864 tokenization_utils.py:517] Adding Ġ<LANGUAGE to the vocabulary
# I1113 19:27:11.558069 140299533100864 tokenization_utils.py:517] Adding Ġ<ORDINAL to the vocabulary
# I1113 19:27:11.559689 140299533100864 tokenization_utils.py:517] Adding Ġ<LOCATION to the vocabulary
# I1113 19:27:11.561450 140299533100864 tokenization_utils.py:517] Adding Ġ<ORGANIZATION to the vocabulary
# I1113 19:27:11.563280 140299533100864 tokenization_utils.py:517] Adding Ġ<PERCENT to the vocabulary
# I1113 19:27:11.565130 140299533100864 tokenization_utils.py:517] Adding <PRODUCT to the vocabulary
# I1113 19:27:11.566938 140299533100864 tokenization_utils.py:517] Adding <TIME to the vocabulary
# I1113 19:27:11.568748 140299533100864 tokenization_utils.py:517] Adding <QUANTITY to the vocabulary
# I1113 19:27:11.570563 140299533100864 tokenization_utils.py:517] Adding <EVENT to the vocabulary
# I1113 19:27:11.572406 140299533100864 tokenization_utils.py:517] Adding <DATE to the vocabulary
# I1113 19:27:11.574282 140299533100864 tokenization_utils.py:517] Adding <CARDINAL to the vocabulary
# I1113 19:27:11.576138 140299533100864 tokenization_utils.py:517] Adding <MONEY to the vocabulary
# I1113 19:27:11.577927 140299533100864 tokenization_utils.py:517] Adding <LAW to the vocabulary
# I1113 19:27:11.579682 140299533100864 tokenization_utils.py:517] Adding <WORK_OF_ART to the vocabulary
# I1113 19:27:11.581468 140299533100864 tokenization_utils.py:517] Adding <PERSON to the vocabulary
# I1113 19:27:11.583273 140299533100864 tokenization_utils.py:517] Adding <NORP to the vocabulary
# I1113 19:27:11.585071 140299533100864 tokenization_utils.py:517] Adding <LANGUAGE to the vocabulary
# I1113 19:27:11.586873 140299533100864 tokenization_utils.py:517] Adding <ORDINAL to the vocabulary
# I1113 19:27:11.588661 140299533100864 tokenization_utils.py:517] Adding <LOCATION to the vocabulary
# I1113 19:27:11.590435 140299533100864 tokenization_utils.py:517] Adding <ORGANIZATION to the vocabulary
# I1113 19:27:11.592318 140299533100864 tokenization_utils.py:517] Adding <PERCENT to the vocabulary
# I1113 19:27:11.594115 140299533100864 tokenization_utils.py:517] Adding _1> to the vocabulary
# I1113 19:27:11.595891 140299533100864 tokenization_utils.py:517] Adding _2> to the vocabulary
# I1113 19:27:11.597667 140299533100864 tokenization_utils.py:517] Adding _3> to the vocabulary
# I1113 19:27:11.599429 140299533100864 tokenization_utils.py:517] Adding _4> to the vocabulary
# I1113 19:27:11.601307 140299533100864 tokenization_utils.py:517] Adding _5> to the vocabulary
# I1113 19:27:11.603106 140299533100864 tokenization_utils.py:517] Adding _6> to the vocabulary
# I1113 19:27:11.604887 140299533100864 tokenization_utils.py:517] Adding _7> to the vocabulary
# I1113 19:27:11.606667 140299533100864 tokenization_utils.py:517] Adding _8> to the vocabulary
# I1113 19:27:11.608447 140299533100864 tokenization_utils.py:517] Adding _9> to the vocabulary
# I1113 19:27:11.610240 140299533100864 tokenization_utils.py:517] Adding _10> to the vocabulary
# I1113 19:27:11.612026 140299533100864 tokenization_utils.py:517] Adding _11> to the vocabulary
# I1113 19:27:11.613828 140299533100864 tokenization_utils.py:517] Adding _12> to the vocabulary
# I1113 19:27:11.615583 140299533100864 tokenization_utils.py:517] Adding _13> to the vocabulary
# I1113 19:27:11.617395 140299533100864 tokenization_utils.py:517] Adding _14> to the vocabulary
# I1113 19:27:11.619174 140299533100864 tokenization_utils.py:517] Adding _15> to the vocabulary
# I1113 19:27:11.620983 140299533100864 tokenization_utils.py:517] Adding _16> to the vocabulary
# I1113 19:27:11.622752 140299533100864 tokenization_utils.py:517] Adding _17> to the vocabulary
# I1113 19:27:11.624536 140299533100864 tokenization_utils.py:517] Adding _18> to the vocabulary
# I1113 19:27:11.626354 140299533100864 tokenization_utils.py:517] Adding _19> to the vocabulary
# I1113 19:27:11.628192 140299533100864 tokenization_utils.py:517] Adding _20> to the vocabulary
# I1113 19:27:11.630038 140299533100864 tokenization_utils.py:517] Adding _21> to the vocabulary
# I1113 19:27:11.631808 140299533100864 tokenization_utils.py:517] Adding _22> to the vocabulary
# I1113 19:27:11.633635 140299533100864 tokenization_utils.py:517] Adding _23> to the vocabulary
# I1113 19:27:11.635419 140299533100864 tokenization_utils.py:517] Adding _24> to the vocabulary
# I1113 19:27:11.637251 140299533100864 tokenization_utils.py:517] Adding _25> to the vocabulary
# I1113 19:27:11.639036 140299533100864 tokenization_utils.py:517] Adding _26> to the vocabulary
# I1113 19:27:11.640811 140299533100864 tokenization_utils.py:517] Adding _27> to the vocabulary
# I1113 19:27:11.642511 140299533100864 tokenization_utils.py:517] Adding _28> to the vocabulary
# I1113 19:27:11.644356 140299533100864 tokenization_utils.py:517] Adding _29> to the vocabulary
# I1113 19:27:11.646190 140299533100864 tokenization_utils.py:517] Adding _30> to the vocabulary
# I1113 19:27:11.647968 140299533100864 tokenization_utils.py:517] Adding _31> to the vocabulary
# I1113 19:27:11.649823 140299533100864 tokenization_utils.py:517] Adding _32> to the vocabulary
# I1113 19:27:11.651581 140299533100864 tokenization_utils.py:517] Adding _33> to the vocabulary
# I1113 19:27:11.653384 140299533100864 tokenization_utils.py:517] Adding _34> to the vocabulary
# I1113 19:27:11.655178 140299533100864 tokenization_utils.py:517] Adding _35> to the vocabulary
# I1113 19:27:11.657122 140299533100864 tokenization_utils.py:517] Adding _36> to the vocabulary
# I1113 19:27:11.658907 140299533100864 tokenization_utils.py:517] Adding _37> to the vocabulary
# I1113 19:27:11.660676 140299533100864 tokenization_utils.py:517] Adding _38> to the vocabulary
# I1113 19:27:11.662440 140299533100864 tokenization_utils.py:517] Adding _39> to the vocabulary
# I1113 19:27:11.664329 140299533100864 tokenization_utils.py:517] Adding _40> to the vocabulary
# I1113 19:27:11.666191 140299533100864 tokenization_utils.py:517] Adding _41> to the vocabulary
# I1113 19:27:11.667971 140299533100864 tokenization_utils.py:517] Adding _42> to the vocabulary
# I1113 19:27:11.669755 140299533100864 tokenization_utils.py:517] Adding _43> to the vocabulary
# I1113 19:27:11.671507 140299533100864 tokenization_utils.py:517] Adding _44> to the vocabulary
# I1113 19:27:11.673314 140299533100864 tokenization_utils.py:517] Adding _45> to the vocabulary
# I1113 19:27:11.675102 140299533100864 tokenization_utils.py:517] Adding _46> to the vocabulary
# I1113 19:27:11.676871 140299533100864 tokenization_utils.py:517] Adding _47> to the vocabulary
# I1113 19:27:11.678644 140299533100864 tokenization_utils.py:517] Adding _48> to the vocabulary
# I1113 19:27:11.680408 140299533100864 tokenization_utils.py:517] Adding _49> to the vocabulary
# I1113 19:27:11.682241 140299533100864 tokenization_utils.py:517] Adding _50> to the vocabulary
# I1113 19:27:11.684034 140299533100864 tokenization_utils.py:517] Adding _51> to the vocabulary
# I1113 19:27:11.685983 140299533100864 tokenization_utils.py:517] Adding _52> to the vocabulary
# I1113 19:27:11.687686 140299533100864 tokenization_utils.py:517] Adding _53> to the vocabulary
# I1113 19:27:11.689454 140299533100864 tokenization_utils.py:517] Adding _54> to the vocabulary
# I1113 19:27:11.691282 140299533100864 tokenization_utils.py:517] Adding _55> to the vocabulary
# I1113 19:27:11.693060 140299533100864 tokenization_utils.py:517] Adding _56> to the vocabulary
# I1113 19:27:11.694870 140299533100864 tokenization_utils.py:517] Adding _57> to the vocabulary
# I1113 19:27:11.696646 140299533100864 tokenization_utils.py:517] Adding _58> to the vocabulary
# I1113 19:27:11.701264 140299533100864 tokenization_utils.py:517] Adding _59> to the vocabulary
# I1113 19:27:11.703091 140299533100864 tokenization_utils.py:517] Adding _60> to the vocabulary
# I1113 19:27:11.704904 140299533100864 tokenization_utils.py:517] Adding _61> to the vocabulary
# I1113 19:27:11.706727 140299533100864 tokenization_utils.py:517] Adding _62> to the vocabulary
# I1113 19:27:11.708485 140299533100864 tokenization_utils.py:517] Adding _63> to the vocabulary
# I1113 19:27:11.710314 140299533100864 tokenization_utils.py:517] Adding _64> to the vocabulary
# I1113 19:27:11.712110 140299533100864 tokenization_utils.py:517] Adding _65> to the vocabulary
# I1113 19:27:11.713902 140299533100864 tokenization_utils.py:517] Adding _66> to the vocabulary
# I1113 19:27:11.715782 140299533100864 tokenization_utils.py:517] Adding _67> to the vocabulary
# I1113 19:27:11.717502 140299533100864 tokenization_utils.py:517] Adding _68> to the vocabulary
# I1113 19:27:11.719323 140299533100864 tokenization_utils.py:517] Adding _69> to the vocabulary
# I1113 19:27:11.721108 140299533100864 tokenization_utils.py:517] Adding _70> to the vocabulary
# I1113 19:27:11.722885 140299533100864 tokenization_utils.py:517] Adding _71> to the vocabulary
# I1113 19:27:11.724656 140299533100864 tokenization_utils.py:517] Adding _72> to the vocabulary
# I1113 19:27:11.726447 140299533100864 tokenization_utils.py:517] Adding _73> to the vocabulary
# I1113 19:27:11.728270 140299533100864 tokenization_utils.py:517] Adding _74> to the vocabulary
# I1113 19:27:11.730094 140299533100864 tokenization_utils.py:517] Adding _75> to the vocabulary
# I1113 19:27:11.731873 140299533100864 tokenization_utils.py:517] Adding _76> to the vocabulary
# I1113 19:27:11.733751 140299533100864 tokenization_utils.py:517] Adding _77> to the vocabulary
# I1113 19:27:11.735528 140299533100864 tokenization_utils.py:517] Adding _78> to the vocabulary
# I1113 19:27:11.737394 140299533100864 tokenization_utils.py:517] Adding _79> to the vocabulary
# I1113 19:27:11.739226 140299533100864 tokenization_utils.py:517] Adding _80> to the vocabulary
# I1113 19:27:11.740937 140299533100864 tokenization_utils.py:517] Adding _81> to the vocabulary
# I1113 19:27:11.742794 140299533100864 tokenization_utils.py:517] Adding _82> to the vocabulary
# I1113 19:27:11.744632 140299533100864 tokenization_utils.py:517] Adding _83> to the vocabulary
# I1113 19:27:11.746432 140299533100864 tokenization_utils.py:517] Adding _84> to the vocabulary
# I1113 19:27:11.748349 140299533100864 tokenization_utils.py:517] Adding _85> to the vocabulary
# I1113 19:27:11.750168 140299533100864 tokenization_utils.py:517] Adding _86> to the vocabulary
# I1113 19:27:11.751985 140299533100864 tokenization_utils.py:517] Adding _87> to the vocabulary
# I1113 19:27:11.753833 140299533100864 tokenization_utils.py:517] Adding _88> to the vocabulary
# I1113 19:27:11.755659 140299533100864 tokenization_utils.py:517] Adding _89> to the vocabulary
# I1113 19:27:11.757456 140299533100864 tokenization_utils.py:517] Adding _90> to the vocabulary
# I1113 19:27:11.759293 140299533100864 tokenization_utils.py:517] Adding _91> to the vocabulary
# I1113 19:27:11.761106 140299533100864 tokenization_utils.py:517] Adding _92> to the vocabulary
# I1113 19:27:11.762920 140299533100864 tokenization_utils.py:517] Adding _93> to the vocabulary
# I1113 19:27:11.764759 140299533100864 tokenization_utils.py:517] Adding _94> to the vocabulary
# I1113 19:27:11.766547 140299533100864 tokenization_utils.py:517] Adding _95> to the vocabulary
# I1113 19:27:11.768396 140299533100864 tokenization_utils.py:517] Adding _96> to the vocabulary
# I1113 19:27:11.770239 140299533100864 tokenization_utils.py:517] Adding _97> to the vocabulary
# I1113 19:27:11.772067 140299533100864 tokenization_utils.py:517] Adding _98> to the vocabulary
# I1113 19:27:11.773891 140299533100864 tokenization_utils.py:517] Adding _99> to the vocabulary
# I1113 19:27:11.775732 140299533100864 tokenization_utils.py:517] Adding _100> to the vocabulary
# ('/home/mroemmele/question_generation/gpt2_tokenizer_vocab/vocab.json',
#  '/home/mroemmele/question_generation/gpt2_tokenizer_vocab/merges.txt',
#  '/home/mroemmele/question_generation/gpt2_tokenizer_vocab/special_tokens_map.json',
#  '/home/mroemmele/question_generation/gpt2_tokenizer_vocab/added_tokens.json')

# %%
def tokenize_fn(tokenizer, text):
    # Add designated marker ("|") after special tokens so subsequent token will have correct whitespace indicator
    text = re.sub("</?[A-Z]+_?[0-9]*>",
                  lambda match: match.group() + "|",
                  text)
    text = re.sub("(<{})(_[0-9]+>)".format("|".join(data_utils.ENTITY_TAGS)),
                  lambda match: " ".join(match.groups()),
                  text)
    text = re.sub("\s<" + "({})".format("|".join(data_utils.ENTITY_TAGS)),
                  lambda match: " Ġ" + match.group().strip(),
                  text)
    tokens = tokenizer.tokenize(text)
    tokens = [token for token in tokens if token != "|"]
    return tokens

def detokenize_fn(tokenizer, tokens):
    text = tokenizer.convert_tokens_to_string(tokens)
    text = text.replace("| ","")
    text = text.replace("<ANSWER>", " <ANSWER>")
    text = text.replace("</ANSWER>", " </ANSWER>")
    return text

# %%
tok_qg_data = tokenize_data(qg_data['input_text'], qg_data['question'],
                            tokenizer, tokenize_fn)
pandas.DataFrame({**tok_qg_data, **{'tokens_to_tags': qg_data['tokens_to_tags'][:10]}})[:100]
# Out:
#                                                                                                                                                                                                                                                       input_text  \
# 0  The Ġ<ORGANIZATION _1> Ġ( <ORGANIZATION _2> ) Ġchampion <ANSWER> Ġ<ORGANIZATION _3> </ANSWER> Ġdefeated Ġthe Ġ<ORGANIZATION _4> Ġ( <ORGANIZATION _5> ) Ġchampion Ġ<ORGANIZATION _6> Ġ<CARDINAL _1> Ġto Ġearn Ġtheir Ġ<ORDINAL _1> Ġ<ORGANIZATION _7> Ġtitle .
# 1  The Ġ<ORGANIZATION _1> Ġ( <ORGANIZATION _2> ) Ġchampion <ANSWER> Ġ<ORGANIZATION _3> </ANSWER> Ġdefeated Ġthe Ġ<ORGANIZATION _4> Ġ( <ORGANIZATION _5> ) Ġchampion Ġ<ORGANIZATION _6> Ġ<CARDINAL _1> Ġto Ġearn Ġtheir Ġ<ORDINAL _1> Ġ<ORGANIZATION _7> Ġtitle .
# 2  The Ġ<ORGANIZATION _1> Ġ( <ORGANIZATION _2> ) Ġchampion <ANSWER> Ġ<ORGANIZATION _3> </ANSWER> Ġdefeated Ġthe Ġ<ORGANIZATION _4> Ġ( <ORGANIZATION _5> ) Ġchampion Ġ<ORGANIZATION _6> Ġ<CARDINAL _1> Ġto Ġearn Ġtheir Ġ<ORDINAL _1> Ġ<ORGANIZATION _7> Ġtitle .
# 3  The Ġ<ORGANIZATION _1> Ġ( <ORGANIZATION _2> ) Ġchampion Ġ<ORGANIZATION _3> Ġdefeated Ġthe Ġ<ORGANIZATION _4> Ġ( <ORGANIZATION _5> ) Ġchampion <ANSWER> Ġ<ORGANIZATION _6> </ANSWER> Ġ<CARDINAL _1> Ġto Ġearn Ġtheir Ġ<ORDINAL _1> Ġ<ORGANIZATION _7> Ġtitle .
# 4  The Ġ<ORGANIZATION _1> Ġ( <ORGANIZATION _2> ) Ġchampion Ġ<ORGANIZATION _3> Ġdefeated Ġthe Ġ<ORGANIZATION _4> Ġ( <ORGANIZATION _5> ) Ġchampion <ANSWER> Ġ<ORGANIZATION _6> </ANSWER> Ġ<CARDINAL _1> Ġto Ġearn Ġtheir Ġ<ORDINAL _1> Ġ<ORGANIZATION _7> Ġtitle .
# 5  The Ġ<ORGANIZATION _1> Ġ( <ORGANIZATION _2> ) Ġchampion Ġ<ORGANIZATION _3> Ġdefeated Ġthe Ġ<ORGANIZATION _4> Ġ( <ORGANIZATION _5> ) Ġchampion <ANSWER> Ġ<ORGANIZATION _6> </ANSWER> Ġ<CARDINAL _1> Ġto Ġearn Ġtheir Ġ<ORDINAL _1> Ġ<ORGANIZATION _7> Ġtitle .
# 6  The Ġgame Ġwas Ġplayed Ġon Ġ<DATE _1> , Ġat Ġ<LOCATION _1> Ġin Ġthe Ġ<LOCATION _2> Ġat <ANSWER> Ġ<LOCATION _3> , Ġ<LOCATION _4> </ANSWER> .
# 7  The Ġgame Ġwas Ġplayed Ġon Ġ<DATE _1> , Ġat <ANSWER> Ġ<LOCATION _1> </ANSWER> Ġin Ġthe Ġ<LOCATION _2> Ġat Ġ<LOCATION _3> , Ġ<LOCATION _4> .
# 8  The Ġgame Ġwas Ġplayed Ġon Ġ<DATE _1> , Ġat <ANSWER> Ġ<LOCATION _1> Ġin Ġthe Ġ<LOCATION _2> Ġat Ġ<LOCATION _3> , Ġ<LOCATION _4> . </ANSWER>
# 9  The Ġ<ORGANIZATION _1> Ġ( <ORGANIZATION _2> ) Ġchampion <ANSWER> Ġ<ORGANIZATION _3> </ANSWER> Ġdefeated Ġthe Ġ<ORGANIZATION _4> Ġ( <ORGANIZATION _5> ) Ġchampion Ġ<ORGANIZATION _6> Ġ<CARDINAL _1> Ġto Ġearn Ġtheir Ġ<ORDINAL _1> Ġ<ORGANIZATION _7> Ġtitle .
#
#                                                                                            question  \
# 0  Which Ġ<ORGANIZATION _8> Ġteam Ġrepresented Ġthe Ġ<ORGANIZATION _2> Ġat Ġ<ORGANIZATION _7> Ġ50 ?
# 1  Which Ġ<ORGANIZATION _8> Ġteam Ġrepresented Ġthe Ġ<ORGANIZATION _2> Ġat Ġ<ORGANIZATION _7> Ġ50 ?
# 2  Which Ġ<ORGANIZATION _8> Ġteam Ġrepresented Ġthe Ġ<ORGANIZATION _2> Ġat Ġ<ORGANIZATION _7> Ġ50 ?
# 3  Which Ġ<ORGANIZATION _8> Ġteam Ġrepresented Ġthe Ġ<ORGANIZATION _5> Ġat Ġ<ORGANIZATION _7> Ġ50 ?
# 4  Which Ġ<ORGANIZATION _8> Ġteam Ġrepresented Ġthe Ġ<ORGANIZATION _5> Ġat Ġ<ORGANIZATION _7> Ġ50 ?
# 5  Which Ġ<ORGANIZATION _8> Ġteam Ġrepresented Ġthe Ġ<ORGANIZATION _5> Ġat Ġ<ORGANIZATION _7> Ġ50 ?
# 6  Where Ġdid Ġ<EVENT _1> Ġtake Ġplace ?
# 7  Where Ġdid Ġ<EVENT _1> Ġtake Ġplace ?
# 8  Where Ġdid Ġ<EVENT _1> Ġtake Ġplace ?
# 9  Which Ġ<ORGANIZATION _8> Ġteam Ġwon Ġ<EVENT _1> ?
#
#                                                                                                                                                                                                                                                                                                                                                                               tokens_to_tags
# 0  {'American Football Conference': '<ORGANIZATION_1>', 'AFC': '<ORGANIZATION_2>', 'Denver Broncos': '<ORGANIZATION_3>', 'National Football Conference': '<ORGANIZATION_4>', 'NFC': '<ORGANIZATION_5>', 'Carolina Panthers': '<ORGANIZATION_6>', '24–10': '<CARDINAL_1>', 'third': '<ORDINAL_1>', 'Super Bowl': '<ORGANIZATION_7>', 'NFL': '<ORGANIZATION_8>'}
# 1  {'American Football Conference': '<ORGANIZATION_1>', 'AFC': '<ORGANIZATION_2>', 'Denver Broncos': '<ORGANIZATION_3>', 'National Football Conference': '<ORGANIZATION_4>', 'NFC': '<ORGANIZATION_5>', 'Carolina Panthers': '<ORGANIZATION_6>', '24–10': '<CARDINAL_1>', 'third': '<ORDINAL_1>', 'Super Bowl': '<ORGANIZATION_7>', 'NFL': '<ORGANIZATION_8>'}
# 2  {'American Football Conference': '<ORGANIZATION_1>', 'AFC': '<ORGANIZATION_2>', 'Denver Broncos': '<ORGANIZATION_3>', 'National Football Conference': '<ORGANIZATION_4>', 'NFC': '<ORGANIZATION_5>', 'Carolina Panthers': '<ORGANIZATION_6>', '24–10': '<CARDINAL_1>', 'third': '<ORDINAL_1>', 'Super Bowl': '<ORGANIZATION_7>', 'NFL': '<ORGANIZATION_8>'}
# 3  {'American Football Conference': '<ORGANIZATION_1>', 'AFC': '<ORGANIZATION_2>', 'Denver Broncos': '<ORGANIZATION_3>', 'National Football Conference': '<ORGANIZATION_4>', 'NFC': '<ORGANIZATION_5>', 'Carolina Panthers': '<ORGANIZATION_6>', '24–10': '<CARDINAL_1>', 'third': '<ORDINAL_1>', 'Super Bowl': '<ORGANIZATION_7>', 'NFL': '<ORGANIZATION_8>'}
# 4  {'American Football Conference': '<ORGANIZATION_1>', 'AFC': '<ORGANIZATION_2>', 'Denver Broncos': '<ORGANIZATION_3>', 'National Football Conference': '<ORGANIZATION_4>', 'NFC': '<ORGANIZATION_5>', 'Carolina Panthers': '<ORGANIZATION_6>', '24–10': '<CARDINAL_1>', 'third': '<ORDINAL_1>', 'Super Bowl': '<ORGANIZATION_7>', 'NFL': '<ORGANIZATION_8>'}
# 5  {'American Football Conference': '<ORGANIZATION_1>', 'AFC': '<ORGANIZATION_2>', 'Denver Broncos': '<ORGANIZATION_3>', 'National Football Conference': '<ORGANIZATION_4>', 'NFC': '<ORGANIZATION_5>', 'Carolina Panthers': '<ORGANIZATION_6>', '24–10': '<CARDINAL_1>', 'third': '<ORDINAL_1>', 'Super Bowl': '<ORGANIZATION_7>', 'NFL': '<ORGANIZATION_8>'}
# 6  {'February 7, 2016': '<DATE_1>', 'Levi's Stadium': '<LOCATION_1>', 'San Francisco Bay Area': '<LOCATION_2>', 'Santa Clara': '<LOCATION_3>', 'California': '<LOCATION_4>', 'Super Bowl 50': '<EVENT_1>'}
# 7  {'February 7, 2016': '<DATE_1>', 'Levi's Stadium': '<LOCATION_1>', 'San Francisco Bay Area': '<LOCATION_2>', 'Santa Clara': '<LOCATION_3>', 'California': '<LOCATION_4>', 'Super Bowl 50': '<EVENT_1>'}
# 8  {'February 7, 2016': '<DATE_1>', 'Levi's Stadium': '<LOCATION_1>', 'San Francisco Bay Area': '<LOCATION_2>', 'Santa Clara': '<LOCATION_3>', 'California': '<LOCATION_4>', 'Super Bowl 50': '<EVENT_1>'}
# 9  {'American Football Conference': '<ORGANIZATION_1>', 'AFC': '<ORGANIZATION_2>', 'Denver Broncos': '<ORGANIZATION_3>', 'National Football Conference': '<ORGANIZATION_4>', 'NFC': '<ORGANIZATION_5>', 'Carolina Panthers': '<ORGANIZATION_6>', '24–10': '<CARDINAL_1>', 'third': '<ORDINAL_1>', 'Super Bowl': '<ORGANIZATION_7>', 'NFL': '<ORGANIZATION_8>', 'Super Bowl 50': '<EVENT_1>'}

# %%
'''Save the tokenized dataset'''

data_dir = "/home/mroemmele/question_generation/squad_gpt2_tok_entity_masked_data"

if not os.path.isdir(os.path.join(data_dir, partition)):
    os.mkdir(os.path.join(data_dir, partition))
    
with open(os.path.join(data_dir, partition, 'answer_sents.txt'), 'w') as f:
    f.write("\n".join(tok_qg_data['input_text']))

with open(os.path.join(data_dir, partition, 'questions.txt'), 'w') as f:
    f.write("\n".join(tok_qg_data['question']))

# %%
detokenize_fn(tokenizer, tok_qg_data['input_text'][0].split(" "))
# Out:
# 'The <ORGANIZATION_1> (<ORGANIZATION_2>) champion <ANSWER> <ORGANIZATION_3> </ANSWER> defeated the <ORGANIZATION_4> (<ORGANIZATION_5>) champion <ORGANIZATION_6> <CARDINAL_1> to earn their <ORDINAL_1> <ORGANIZATION_7> title.'
